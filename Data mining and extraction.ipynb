# %%
# Data Mining and extraction

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Web Scraping using Beautifulsoup
# Web Scraping means to collect data from the Internet. As a beginner in data science, you must have seen CSV files on the Internet distributed by some popular websites like Kaggle and other govt websites. The data is prepared by either collecting and writing using standard methods or by scraping it from the Internet.
# Web Scraping to Create a CSV File
# So we need two primary packages for this task, BeautifulSoup, urllib and Selenium. We can easily install both these packages using the pip command - pip install bs4, pip install urllib3, pip selenium.

# %%
# I will scrape data from Flipkart and create a CSV file from that data. It's not that difficult what it seems. Let's get
# our hands dirty with web scraping to create a CSV file using python. I will start by importing the necessary packages 
# that we need for this task. So let's get started.
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import requests

my_url="https://www.flipkart.com/mens-tshirts/pr?sid=clo,ash,ank,edy&fm=neo%2Fmerchandising&iid=M_43b820da-242c-4d41-9e7f-b79113781a01_1_372UD5BXDFYS_MC.IF56C41VGEYS&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Fashion~Men%27s%2BTop%2BWear~Men%27s%2BT-Shirts_IF56C41VGEYS&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&cid=IF56C41VGEYS"
# uClient = uReq(my_url)
# page_html = uClient.read()
# uClient.close()
flipkart = requests.get(my_url)
page_html = flipkart.content

# %%
page_html
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.8dd48d.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4e719.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png"/><link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png"/><link rel="apple-touch-icon" href="/apple-touch-icon-57x57.png"/><meta name="twitter:card" content="app"><meta name="twitter:site" content="@flipkart"><meta name="twitter:creator" content="@flipkart"><meta name="twitter:title" content="T-shirts for men at Best Price in India | Flipkart"><meta name="twitter:description" content="Shop for electronics, apparels & more using our Flipkart app Free shipping & COD."><meta name="twitter:app:country" content="in"><meta name="al:ios:app_name" content="Flipkart"><meta name="al:ios:app_store_id" content="742044692"><meta name="twitter:app:name:iphone" content="Flipkart"><meta name="twitter:app:id:iphone" content="742044692"><meta name="twitter:app:url:iphone" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:ipad" content="Flipkart"><meta name="twitter:app:id:ipad" content="742044692"><meta name="twitter:app:url:ipad" content="http://dl.flipkart.com/dl/home?"><meta name="twitter:app:name:googleplay" content="Flipkart"><meta name="twitter:app:id:googleplay" content="com.flipkart.android"><meta name="twitter:app:url:googleplay" content="http://dl.flipkart.com/dl/home?"><style>#container {\n\t\t\theight: 100%;\n\t\t}</style>  <link rel="stylesheet" href="///fk-cp-zion/css/Browse.chunk.83db80.css"/><title>T-shirts for men at Best Price in India | Flipkart</title><meta name="og_title" property="og:title" content="T-shirts for men at Best Price in India | Flipkart"/><meta name="Keywords" content="Mens Tshirts"/> <meta name="Description" content="Shop T-shirts for men at the best price in India on Flipkart. Explore a wide range of styles, colors, and fits for every occasion. \xe2\x9c\x85 Free Shipping \xe2\x9c\x85 COD \xe2\x9c\x85 Easy Returns."/><meta property="og:description" content="Shop T-shirts for men at the best price in India on Flipkart. Explore a wide range of styles, colors, and fits for every occasion. \xe2\x9c\x85 Free Shipping \xe2\x9c\x85 COD \xe2\x9c\x85 Easy Returns."/>  <link rel="canonical" href="https://www.flipkart.com/clothing-and-accessories/topwear/tshirts/mens-tshirts/pr?sid&#x3D;clo,ash,ank,edy"/>     <meta name="og_url" property="og:url" content="https://www.flipkart.com/clothing-and-accessories/topwear/tshirts/mens-tshirts/pr?sid&#x3D;clo,ash,ank,edy"/><meta name="msvalidate.01" content="F4EEB3A0AFFDD385992A06E6920C0AC3"/> <!--[if IE 9 ]>\n\t<script nonce="9423860472277769427">\n\t\twindow.browserVersion = \'IE9\';\n\t\tdocument.documentElement.className += \' ie9\';\n\t</script>\n\t<![endif]--><!--[if !IE]><!--><script nonce="9423860472277769427">if (/*@cc_on!@*/false) {\n\t\t\twindow.browserVersion = \'IE10\';\n\t\t\tdocument.documentEl ...

# %%
page_soup = soup(page_html, "html.parser")
page_soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.8dd48d.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4e719.css" rel="stylesheet"/><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="102988293558" property="fb:page_id"/><meta content="658873552,624500995,100000233612389" property="fb:admins"/><link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/><link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/><meta content="website" property="og:type"/><meta content="Flipkart.com" name="og_site_name" property="og:site_name"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/><meta content="app" name="twitter:card"/><meta content="@flipkart" name="twitter:site"/><meta content="@flipkart" name="twitter:creator"/><meta content="T-shirts for men at Best Price in India | Flipkart" name="twitter:title"/><meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/><meta content="in" name="twitter:app:country"/><meta content="Flipkart" name="al:ios:app_name"/><meta content="742044692" name="al:ios:app_store_id"/><meta content="Flipkart" name="twitter:app:name:iphone"/><meta content="742044692" name="twitter:app:id:iphone"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/><meta content="Flipkart" name="twitter:app:name:ipad"/><meta content="742044692" name="twitter:app:id:ipad"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/><meta content="Flipkart" name="twitter:app:name:googleplay"/><meta content="com.flipkart.android" name="twitter:app:id:googleplay"/><meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/><style>#container {
# 			height: 100%;
# 		}</style> <link href="///fk-cp-zion/css/Browse.chunk.83db80.css" rel="stylesheet"/><title>T-shirts for men at Best Price in India | Flipkart</title><meta content="T-shirts for men at Best Price in India | Flipkart" name="og_title" property="og:title"><meta content="Mens Tshirts" name="Keywords"> <meta content="Shop T-shirts for men at the best price in India on Flipkart. Explore a wide range of styles, colors, and fits for every occasion. ✅ Free Shipping ✅ COD ✅ Easy Returns." name="Description"><meta content="Shop T-shirts for men at the best price in India on Flipkart. Explore a wide range of styles, colors, and fits for every occasion. ✅ Free Shipping ✅ COD ✅ Easy Returns." property="og:description"> <link href="https://www.flipkart.com/clothing-and-accessories/topwear/tshirts/mens-tshirts/pr?sid=clo,ash,ank,edy" rel="canonical"/> <meta content="https://www.flipkart.com/clothing-and-accessories/topwear/tshirts/mens-tshirts/pr?sid=clo,ash,ank,edy" name="og_url" property="og:url"><meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01"> <!--[if IE 9 ]>
# 	<script nonce="9423860472277769427">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]--><!--[if !IE]><!--><script nonce="9423860472277769427">if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}</script><!--<![endif]--> <link href="https://www.flipkart.com/mens-tshirts/pr?sid=clo%2Cash%2Cank%2Cedy&amp;fm=neo%2Fmerchandising&amp;iid=M_43b820da-242c-4d41-9e7f-b79113781a01_1_372UD5BXDFYS_MC.IF56C41VGEYS&amp;otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Fashion%7EMen%27s%2BTop%2BWear%7EMen%27s%2BT-Shirts_IF56C41VGEYS&amp;otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&amp;cid=IF56C41VGEYS&amp;page=2" id="next-page-link-tag" rel="next"/><script nonce="9423860472277769427">!function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#
# 		if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#
#         // web-vitals polyfill for FID
#         !function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-594691041"></script><script nonce="9423860472277769427">window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments)};
# 		gtag('js', new Date());
#
# 		const pageUri = window.location.pathname;
#     		if (pageUri && pageUri.includes('/travel')) {
# 			gtag('config', 'AW-16596706887');
# 		}</script></meta></meta></meta></meta></meta></meta></head><body><div id="container"><div><div class="krHvwW"><div class="J+HqMZ"><div class="LOe-Xr"></div><div class="Ja1j8k"><div class="ngOQ7L"><div class="F9+fd2"><a href="/"><img alt="Flipkart" class="W5mR4e" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="MwbhDR" href="/plus">Explore<!-- --> <span class="s4NJ5L">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="kRd8Cs"><form action="/search" class="Hy6F9O header-form-search" method="GET"><div class="col-12-12 BnmXvV"><div class="MoPwtI"><input autocomplete="off" class="zDPmFV" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/></div><button class="MJG8Up" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill="#2874F1" fill-rule="evenodd"><path class="EwE-Fa" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203"></path><path class="EwE-Fa" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467"></path></g></svg></button><input name="otracker" type="hidden" value="search"/><input name="otracker1" type="hidden" value="search"/><input name="marketplace" type="hidden" value="FLIPKART"/><input name="as-show" type="hidden" value="off"/><input name="as" type="hidden" value="off"/></div><ul class="col-12-12 bbjHWC"></ul></form></div><div class="RbF1Du UB4mMK"><div class="UL9nZx"><div class="tP+nZg _2E9UgX"><div><a class="wsejfv" href="/account/login?ret=/mens-tshirts/pr%3Fsid%3Dclo%2Cash%2Cank%2Cedy%26fm%3Dneo%252Fmerchandising%26iid%3DM_43b820da-242c-4d41-9e7f-b79113781a01_1_372UD5BXDFYS_MC.IF56C41VGEYS%26otracker%3Dhp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Fashion~Men%2527s%252BTop%252BWear~Men%2527s%252BT-Shirts_IF56C41VGEYS%26otracker1%3Dhp_rich_navigation_PINNED_neo%252Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all%26cid%3DIF56C41VGEYS">Login</a></div></div></div></div><div class="RbF1Du"><a class="CDJO0-" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a></div><div class="RbF1Du"><div class="UL9nZx"><div class="tP+nZg _2E9UgX"><div><div class="_3ZeUN+"> <!-- -->More<!-- --> </div></div></div><svg class="Wto0b0" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="-dC5Le" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div></div><div class="RbF1Du"><div class="tP+nZg"><div class="cjMG1q"><a class="_9Wy27C" href="/viewcart?exploreMode=true&amp;preference=FLIPKART"><svg class="GAbRIN" height="14" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg"><path class="cziJ98" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866-.584-1.593-1.38-1.814l2.423-8.832c.12-.433-.206-.86-.655-.86" fill="#fff"></path></svg><span>Cart</span></a></div></div></div></div><div class="LOe-Xr"></div></div><div class="DlQjC4"></div></div><div class="_5M58Mb"></div><div class="nt6sNV JxFEK3 _48O0EI"><div class="DOjaWF YJG4Cf"><div class="DOjaWF gdgoEp col-2-12" style="flex:0 0 280px;max-width:280px;padding:0px 10px 0px 0px"><div class="cPHDOP col-12-12" styl ...
# <h2 data-end="163" data-start="133">Buy T-Shirts for Men Online</h2>
# <h3><br/>
# From Basics to Bold – Explore Men’s T-Shirt Collection</h3>
#
#
# <p data-end="694" data-start="165">Men’s t-shirts are a wardrobe essential that blend comfort, versatility, and self-expression. From plain cotton tees perfect for layering, to bold graphic prints that showcase your personality, t-shirts are the one piece you can wear across seasons, styles, and occasions. Whether you're updating your basics or experimenting with streetwear trends, this collection features a curated mix of styles, fits, and fabrics to suit every need. Browse everyday essentials, gym-ready activewear, or statement pieces, all in one place.</p>
# <div data-end="694" data-start="165"></div>
# <h2 data-end="329" data-start="285">Popular T Shirt Styles for Every Wardrobe</h2>
# <p data-end="378" data-start="202"></p>
# <p data-end="378" data-start="202">Some t shirt styles never go out of fashion. Others are quickly rising in demand. Explore a mix of classic and on trend styles that offer something for every mood, season and occasion.</p>
# <p data-end="753" data-start="541"></p>
# <h3 data-end="753" data-start="541">Polo T Shirts</h3>
# <p data-end="753" data-start="541"></p>
# <article data-scroll-anchor="true" data-testid="conversation-turn-26" dir="auto">
# <p data-end="419" data-start="138">When you want to keep it casual but still look put together, <a href="/q/polo-t-shirts-men">polo t shirts</a> are the perfect choice. With their collared design and structured feel, they work well for relaxed office days, casual outings or anytime you want a bit more polish without going formal.</p>
# <div data-end="419" data-start="138"></div>
# </article>
# <h3 data-end="947" data-start="755">Oversized T Shirts</h3>
# <p data-end="947" data-start="755"><br data-end="780" data-start="777"/>
# Relaxed, roomy and inspired by streetwear, <a href="/q/oversized-t-shirt-men">oversized t shirts</a> combine comfort with modern style. Pair them with joggers or denims for a laid back yet intentional look.<br/>
#  </p>
# <h3 data-end="753" data-start="541">Graphic Printed T Shirts</h3>
# <p data-end="753" data-start="541"><br data-end="564" data-start="561"/>
# Featuring bold prints, logos or pop culture references, <a href="/q/graphic-tees">graphic tees</a> let your outfit speak. Ideal for casual outings or relaxed weekends, they bring in just the right amount of personality.<br/>
#  </p>
# <h3 data-end="947" data-start="755">Solid T Shirts</h3>
# <p data-end="1142" data-start="949"><br data-end="970" data-start="967"/>
# Easy to match and endlessly versatile, <a href="/mens-tshirts/solid~pattern/pr?sid=clo,ash,ank,edy">solid colour t shirts</a> in black, <a href="/q/plain-white-tshirts">white</a>, navy or muted tones are wardrobe essentials. Wear them solo or layer under shirts and jackets.<br/>
#  </p>
# <h3 data-end="1351" data-start="1144">Activewear T Shirts</h3>
# <p data-end="1351" data-start="1144"><br data-end="1170" data-start="1167"/>
# Popularly know as sports or <a href="/q/gym-t-shirts-for-men">gym t shirts</a> these designed for movement and built with breathable fabrics, these t shirts work well on commutes or during long hours out and about. They blend function with everyday ease.<br/>
#  </p>
# <h3 data-end="1532" data-start="1353">Striped and Colorblock T Shirts</h3>
# <p data-end="1532" data-start="1353"><br/>
# Add pattern without going over the top. These styles offer clean lines and balanced contrast, making them a smart choice for casual dressing.<br/>
# <br/>
# That’s just a glimpse. There’s a lot more waiting for you, but we’ll let you do the digging. Take your time, browse around, and find the t shirt that fits your style just right.</p>
# <div data-end="1760" data-start="1534"></div>
# <h2 data-end="228" data-start="189">Why Buy T Shirts for Men on Flipkart</h2>
# <p data-end="771" data-start="230">From trusted brands to budget friendly picks, Flipkart brings you one of the widest selections of men’s t shirts online. Whether you’re looking for everyday basics, trend-driven styles or activewear essentials, you’ll find options in every fit, fabric and price range. Smart filters help you shortlist faster by size, colour or occasion, while detailed product reviews and easy returns make shopping simple and stress free. With regular deals, combos and exclusive launches, refreshing your t shirt collection has never been more convenient.<br/>
# <br/>
# Shop by Sleeve:<br/>
# <br/>
# <a href="/q/full-sleeve-t-shirts">Full sleeve t-shirts</a> | <a href="/mens-tshirts/half-sleeve~sleeve/pr?sid=clo,ash,ank,edy">half sleeve t-shirts</a> | <a href="/q/sleeveless-t-shirt">sleeveless t-shirts</a> <br/>
# <br/>
# Shop by Color:<br/>
# <br/>
# <a href="/q/plain-white-tshirts">White t-shirts</a> | <a href="/mens-tshirts/black~color/pr?sid=clo,ash,ank,edy">Black t-shirts</a> | <a href="/mens-tshirts/navy-blue~color/pr?sid=clo,ash,ank,edy">Navy Blue t-shirts</a> | <a href="/mens-tshirts/grey~color/pr?sid=clo,ash,ank,edy">Grey t-shirts</a><br/>
# <br/>
# Shop by Top Brands:<br/>
# <br/>
# <a href="/mens-tshirts/u-s-polo-assn-~brand/pr?sid=clo,ash,ank,edy">US Polo t-shirts</a> | <a href="/mens-tshirts/puma~brand/pr?sid=clo%2Cash%2Cank%2Cedy">Puma t-shirts</a> | <a href="/mens-tshirts/allen-solly~brand/pr?sid=clo,ash,ank,edy">Allen solly t-shirts</a> | <a href="/mens-tshirts/adidas~brand/pr?sid=clo%2Cash%2Cank%2Cedy">Adiads t-shirts</a> | <a href="/mens-clothing/tshirts/roadster~brand/pr?sid=2oq,s9b,j9y">Roadster t-shirts</a> | <a href="/mens-tshirts/wrogn~brand/pr?sid=clo%2Cash%2Cank%2Cedy">Wrong t-shirts</a> | </p>
# </div></div></div></div><div class="row faqRow"><div class="col gu12 k+w5ye"><div class="KdVeMk"><section class="S5Y075"><h2 class="OxHpdP"><span>Question and Answers</span></h2><ol><li class="jEFpOn"><div class="qNo1gu"><span>Q.What is the biggest size in T-shirts for men?</span></div><div class="_3s97Am"><span>A.You can get XXL(46 cm) as the biggest size in T-shirts for men</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.Do I get different-colored T-shirts with a round neck?</span></div><div class="_3s97Am"><span>A.Choose from multiple colour options in combo offers available in round neck T-shirts.</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.Can I get sleeveless T-shirts for men?</span></div><div class="_3s97Am"><span>A.Many brands offer sleeveless T-shirts for men. You can check online for more options</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.Are these T-shirts comfortable for summer?</span></div><div class="_3s97Am"><span>A.Most T-shirts are made of cotton. Cotton absorbs sweat and helps in the easy evaporation of sweat. This allows our bodies to cool down. So, cotton T-shirts are more comfortable to wear during summers.</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.I wear 38-size shirts. Should I pick the XS size for the T-shirt?</span></div><div class="_3s97Am"><span>A.Size measurements vary from brand to brand. Please check the measurements before making a purchase.</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.How do I know my T-shirt size?</span></div><div class="_3s97Am"><span>A.Firstly, measure your shoulder from the edge of one arm to another. Then measure around your body under the arms at the fullest part of the chest with your arms relaxed. Now measure from the shoulder seam from the outer arm to the cuff. Finally, measure across the neck length from the highest point of the shoulder seam to the bottom hem of the garment.</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.Where can I find a T-shirt for my 19-year-old son?</span></div><div class="_3s97Am"><span>A.You could find T-shirts from XS or S for your teen. You can pick up the size depending on your son’s build.</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.How do I prevent my T-shirt from getting faded?</span></div><div class="_3s97Am"><span>A.Always dry your T-shirt in a cool place, away from direct sunlight. Also, take the inside out of your T-shirt while drying. This way, you could prevent your T-shirt from fading.</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.What do I pair my printed T-shirt with?</span></div><div class="_3s97Am"><span>A.You can wear <a href="/mens-shorts/pr?sid=clo,vua,e8g,kc7">shorts</a>, jeans, <a href="/clothing-and-accessories/bottomwear/cargos/mens-cargos/pr?sid=clo%2Cvua%2Crqy%2Cnli">cargos</a>, joggers, etc.</span></div></li><li class="jEFpOn"><div class="qNo1gu"><span>Q.Can I order more of the same T-shirts?</span></div><div class="_3s97Am"><span>A.Yes, you can order more, depending on the availability of the size that you are ordering for.</span></div></li></ol></section></div></div></div><div><div class="_8K2S+t row"><div class="bowO0w"><div class="AZc3lB">ABOUT</div><a class="bXmsT+" href="/helpcentre?otracker=footer_navlinks">Contact Us</a><a class="bXmsT+" href="https://corporate.flipkart.net/corporate-home">About Us</a><a class="bXmsT+" href="https://www.flipkartcareers.com/?otracker=footer_navlinks">Careers</a><a class="bXmsT+" href="http://stories.flipkart.com/?otracker=footer_navlinks">Flipkart Stories</a><a class="bXmsT+" href="http://stories.flipkart.com/category/top-stories/news/">Press</a><a class="bXmsT+" href="/corporate-information">Corporate Information</a></div><div class="bowO0w"><div class="AZc3lB">GROUP COMPANIES</div><a class="bXmsT+" href="https://www.myntra.com/" rel="noopener noreferrer" target="_blank" title="Myntra">Myntra</a><a class="bXmsT+" href="https: ...
# <p> Buildings Alyssa, Begonia &amp; </p>
# <p> Clove Embassy Tech Village, </p>
# <p> Outer Ring Road, Devarabeesanahalli Village, </p>
# <p> Bengaluru, 560103, </p>
# <p> Karnataka, India</p>
# </div></div></div><div class="AZc3lB">Social</div><div class="mK8LcN"><span class="RbqUpy"><a href="https://www.facebook.com/flipkart"><img height="24" src="data:image/svg+xml;base64,..." width="24"/></a></span><span class="RbqUpy"><a href="https://www.twitter.com/flipkart"><img height="24" src="data:image/svg+xml;base64,..." width="24"/></a></span><span class="RbqUpy"><a href="https://www.youtube.com/flipkart"><img height="24" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/YoutubeLogo_958b78.svg" width="24"/></a></span><span class="RbqUpy"><a href="https://www.instagram.com/flipkart"><img height="20" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/InstagramLogo_854a2c.svg" width="20"/></a></span></div></div></div><div class="bowO0w address"><div class="QYRYF-"><div class="AZc3lB"><span>Registered Office Address:</span></div><div class="iE4xEP"><div class="aL22KS"><div class="KalC6f iE4xEP"><p>Flipkart Internet Private Limited, </p>
# <p> Buildings Alyssa, Begonia &amp; </p>
# <p> Clove Embassy Tech Village, </p>
# <p> Outer Ring Road, Devarabeesanahalli Village, </p>
# <p> Bengaluru, 560103, </p>
# <p> Karnataka, India </p>
# <p> CIN : U51109KA2012PTC066107 </p>
# <p> Telephone: <a href="tel:044-45614700">044-45614700</a> / <a href="tel:044-67415800">044-67415800</a></p>
# </div></div></div></div></div></div><div><div class="pXtEV2"><div><img src="data:image/svg+xml;base64,..."/><a href="https://seller.flipkart.com/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span class="XqVBP0">Become a Seller</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="https://brands.flipkart.com"><span class="XqVBP0">Advertise</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="/the-gift-card-store?otracker=footer_navlinks"><span class="XqVBP0">Gift Cards</span></a></div><div><img src="data:image/svg+xml;base64,..."/><a href="/helpcentre?otracker=footer_navlinks"><span class="XqVBP0">Help Center</span></a></div><span class="T8+RtG">© 2007-<!-- -->2025<!-- --> <span>Flipkart.com</span></span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/payment-method_69e7ec.svg"/></div></div></div></div></footer><div class="XiSiPK AqhsUa"><div class="sRIueJ"><svg class="jY-KQI" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="laqJUS" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg><span>Back to top</span></div></div></div></div> <script id="jsonLD" nonce="9423860472277769427" type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.flipkart.com/tripr-solid-men-mandarin-collar-dark-green-t-shirt/p/itm0d79233a1f312?pid=TSHGZ29HZ45PKUFA&lid=LSTTSHGZ29HZ45PKUFAT38BP8&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy","name":"TRIPR Solid Men Mandarin Collar Dark Green T-Shirt"},{"@type":"ListItem","position":2,"url":"https://www.flipkart.com/n-j-solid-men-polo-neck-purple-t-shirt/p/itma67d8119c5ec0?pid=TSHH6XYXYCCEV6CF&lid=LSTTSHH6XYXYCCEV6CFCNY1W5&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy","name":"N AND J Solid Men Polo Neck Purple T-Shirt"},{"@type":"ListItem","position":3,"url":"https://www.flipkart.com/vebnor-solid-men-round-neck-light-green-t-shirt/p/itm7203b2f94f1ae?pid=TSHH3FVBUBUXSX2U&lid=LSTTSHH3FVBUBUXSX2UFISXVD&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy&spotlightTagId=default_BestsellerId_clo%2Fash%2Fank%2Fedy","name":"VeBNoR Solid Men Round Neck Light Green T-Shirt"},{"@type":"ListItem","position":4,"url":"https://www.flipkart.com/fashion-youth-solid-men-polo-neck-white-t-shirt/p/itm7fa8cb9b2ad84?pid=TSHHBJC82J5BHH8H&lid=LSTTSHHBJC82J5BHH8HSZV0JK&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy","name":"Fashion And Youth Solid Men Polo Neck White T-Shirt"},{"@type":"ListItem","position":5,"url":"https://www.flipkart.com/kajaru-self-design-men-polo-neck-brown-t-shirt/p/itm785a09ad98edd?pid=TSHH6BBTPZCUKET4&lid=LSTTSHH6BBTPZCUKET4CYIHPF&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy","name":"KAJARU Self Design Men Polo Neck Brown T-Shirt"},{"@type":"ListItem","position":6,"url":"https://www.flipkart.com/tripr-solid-men-henley-neck-multicolor-t-shirt/p/itm3a25876323897?pid=TSHH7TSDJC9VKFBD&lid=LSTTSHH7TSDJC9VKFBDP4RFUZ&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy","name":"TRIPR Solid Men Henley Neck Multicolor T-Shirt"},{"@type":"ListItem","position":7,"url":"https://www.flipkart.com/metronaut-printed-men-round-neck-brown-t-shirt/p/itm6f32685520415?pid=TSHHBNTQYJJNHMGP&lid=LSTTSHHBNTQYJJNHMGPCUD65W&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy","name":"METRONAUT Printed Men Round Neck Brown T-Shirt"},{"@type":"ListItem","position":8,"url":"https://www.flipkart.com/metronaut-printed-men-round-neck-silver-t-shirt/p/itmb0319c9e9dafa?pid=TSHHBNTPZRPJUUG9&lid=LSTTSHHBNTPZRPJUUG9HIVTW5&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy","name":"METRONAUT Printed Men Round Neck Silver T-Shirt"},{"@type":"ListItem","position":9,"url":"https://www.flipkart.com/fashion-youth-solid-men-polo-neck-maroon-t-shirt/p/itmee24585545049?pid=TSHHBJC8MCAZ4VYJ&lid=LSTTSHHBJC8MCAZ4VYJ1UF3NV&marketplace=FLIPKART&store=clo%2Fash%2Fank%2Fedy","name":"Fashion And Youth Solid Men Polo N ...
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }</script><script id="is_script" nonce="9423860472277769427">window.__INITIAL_STATE__ = {};</script> <link data-chunk="NavMenu" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/NavMenu.chunk.9995bd.css" rel="stylesheet"/>
# <link data-chunk="SearchFeedback" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/SearchFeedback.chunk.244b23.css" rel="stylesheet"/> <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[132,208]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["NavMenu","SearchFeedback"]}</script>
# <script async="" data-chunk="NavMenu" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/NavMenu.chunk.426bef8b.js"></script>
# <script async="" data-chunk="SearchFeedback" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/js/SearchFeedback.chunk.4cd5047c.js"></script><script nonce="9423860472277769427">window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;</script><script nonce="9423860472277769427">function isMobile(){
# 		if (!!(navigator.userAgentData && navigator.userAgentData.mobile) || navigator.userAgent.indexOf("Mobile") !== -1){
# 			return true;
# 		}
# 		else {
# 			return false;
# 		}
# 	}
#
# 	if ('serviceWorker' in navigator && !isMobile()) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 			navigator.onLine && navigator.serviceWorker.controller && navigator.serviceWorker.controller.postMessage('BANDWIDTH_COMPUTE');
# 			navigator.serviceWorker.addEventListener('message', function (event) {
# 				try {
# 					const bandwidthData = JSON.parse(event.data);
# 					if (bandwidthData && bandwidthData.data) {
# 						window.bandwidth = bandwidthData.data.downlink + '_' + bandwidthData.data.computeMethod + '_' + bandwidthData.data.effectiveType + '_' + bandwidthData.data.type;
# 					}
# 				}catch(err) {
# 					console.error('JSON.parse failed:', err);
# 				}
# 			});
# 		})
# 		.catch(function(err) {
# 			console.log('%c ServiceWorker registration failed: ', "color:red;", err);
# 		});
# 	} else if('serviceWorker' in navigator && isMobile()){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }</script> <script async="" defer="defer" id="omni_script" nonce="9423860472277769427" src="///www/linchpin/batman-returns/omni/omni16.js"></script> </body></html>

# %%
# Now let's see how many HTML containers are present in this link:
list_of_container = page_soup.findAll("div", { "class": "_75nlfW"})
print(len(list_of_container))
# print(soup.prettify(list_of_container[0]))
# Out:
# 10

# %%
container = list_of_container[0]
# print(soup.prettify(container))
list_of_contents = container.findAll("div", {"class": "_1sdMkc LFEi7Z"})
len(list_of_contents)
# Out:
# 4

# %%
card = list_of_contents[0]
print(card)
# Out:
# <div class="_1sdMkc LFEi7Z"><a class="rPDeLR" href="/tripr-solid-men-mandarin-collar-dark-green-t-shirt/p/itm0d79233a1f312?pid=TSHGZ29HZ45PKUFA&amp;lid=LSTTSHGZ29HZ45PKUFAT38BP8&amp;marketplace=FLIPKART&amp;store=clo%2Fash%2Fank%2Fedy&amp;srno=b_1_1&amp;otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Fashion~Men's%2BTop%2BWear~Men's%2BT-Shirts_IF56C41VGEYS&amp;otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&amp;fm=organic&amp;iid=en_48WWgr12EuHz_l12_Df9e6lyvx7A_EdAxsFPt02uc9Ry9nLQdBfbCIPNBb0St-lVDisOb4IjS6Ugbo6t0ogNzPUFjCTyOHoHZs-Z5_PS_w0%3D&amp;ppt=None&amp;ppn=None&amp;ssid=0m1dyt6exs0000001747295069454" rel="noopener noreferrer" target="_blank"><div><div><div class="wvIX4U" style="padding-top:120.00%"><div class="gqcSqV YGE0gZ" style="padding-top:120.00%"><img alt="" class="_53J4C-" src="https://rukminim2.flixcart.com/image/612/612/xif0q/t-shirt/x/y/p/xxl-tpgrblhn-d145-tripr-original-imah3vgf52grhsf6.jpeg?q=70"/></div></div></div></div><div class="jt22zr" style="bottom:4px"></div><div class="oUss6M D05kjV gREhVj"><div class="+7E521"><svg class="N1bADF" height="28" viewbox="0 0 20 16" width="28" xmlns="http://www.w3.org/2000/svg"><path class="x1UMqG" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF"></path></svg></div></div></a><div class="hCKiGj" style="transform:translate3d(0, 0, 0)"><div class="_2ABVdq"><svg class="" height="18" width="62" xmlns="http://www.w3.org/2000/svg"><rect fill="white" height="18" width="62"></rect><path d="M5.82955 6.45455C5.77841 6.02273 5.57102 5.6875 5.20739 5.44886C4.84375 5.21023 4.39773 5.09091 3.86932 5.09091C3.48295 5.09091 3.14489 5.15341 2.85511 5.27841C2.56818 5.40341 2.34375 5.57528 2.18182 5.79403C2.02273 6.01278 1.94318 6.26136 1.94318 6.53977C1.94318 6.77273 1.99858 6.97301 2.10938 7.14062C2.22301 7.3054 2.3679 7.44318 2.54403 7.55398C2.72017 7.66193 2.90483 7.75142 3.09801 7.82244C3.29119 7.89062 3.46875 7.94602 3.63068 7.98864L4.51705 8.22727C4.74432 8.28693 4.99716 8.36932 5.27557 8.47443C5.55682 8.57955 5.82528 8.72301 6.08097 8.90483C6.33949 9.08381 6.55256 9.31392 6.72017 9.59517C6.88778 9.87642 6.97159 10.2216 6.97159 10.6307C6.97159 11.1023 6.84801 11.5284 6.60085 11.9091C6.35653 12.2898 5.99858 12.5923 5.52699 12.8168C5.05824 13.0412 4.48864 13.1534 3.81818 13.1534C3.19318 13.1534 2.65199 13.0526 2.1946 12.8509C1.74006 12.6491 1.3821 12.3679 1.12074 12.0071C0.862216 11.6463 0.715909 11.2273 0.681818 10.75H1.77273C1.80114 11.0795 1.91193 11.3523 2.10511 11.5682C2.30114 11.7812 2.5483 11.9403 2.84659 12.0455C3.14773 12.1477 3.47159 12.1989 3.81818 12.1989C4.22159 12.1989 4.58381 12.1335 4.90483 12.0028C5.22585 11.8693 5.48011 11.6847 5.66761 11.4489C5.85511 11.2102 5.94886 10.9318 5.94886 10.6136C5.94886 10.3239 5.8679 10.0881 5.70597 9.90625C5.54403 9.72443 5.33097 9.5767 5.06676 9.46307C4.80256 9.34943 4.51705 9.25 4.21023 9.16477L3.13636 8.85795C2.45455 8.66193 1.91477 8.3821 1.51705 8.01847C1.11932 7.65483 0.920455 7.17898 0.920455 6.59091C0.920455 6.10227 1.05256 5.67614 1.31676 5.3125C1.58381 4.94602 1.94176 4.66193 2.39062 4.46023C2.84233 4.25568 3.34659 4.15341 3.90341 4.15341C4.46591 4.15341 4.96591 4.25426 5.40341 4.45597C5.84091 4.65483 6.1875 4.92756 6.44318 5.27415C6.7017 5.62074 6.83807 6.0142 6.85227 6.45455H5.82955ZM8.5728 15.4545V6.45455H9.54439V7.49432H9.66371C9.73757 7.38068 9.83984 7.2358 9.97053 7.05966C10.104 6.88068 10.2944 6.72159 10.5415 6.58239C10.7915 6.44034 11.1296 6.36932 11.5558 6.36932C12.1069 6.36932 12.5927 6.5071 13.0131 6.78267C13.4336 7.05824 13.7617 7.44886 13.9975 7.95455C14.2333 8.46023 14.3512 9.05682 14.3512 9.74432C14.3512 10.4375 14.2333 11.0384 13.9975 11.5469C13.7617 12.0526 13.435 12.4446 13.0174 12.723C12.5998 12.9986 12.1183 13.1364 11.57 ...

# %%
image = card.findAll("img", {"class":"_53J4C-"})
print(image[0]['src'])
# Out:
# https://rukminim2.flixcart.com/image/612/612/xif0q/t-shirt/x/y/p/xxl-tpgrblhn-d145-tripr-original-imah3vgf52grhsf6.jpeg?q=70

# %%
brand = card.findAll("div", {"class":"syl9yP"})
brand[0].text
# Out:
# 'TRIPR'

# %%
title = card.findAll("a", {"class":"WKTcLC"})
print(title[0].text)
# title
# Out:
# Men Solid Mandarin Collar Cotton Blend Dark Green T-Shi...

# %%
sales_price = card.findAll('div', {"class": "Nx9bqj"})
sales_price[0].text
# Out:
# '₹253'

# %%
actual_price = card.findAll('div', {"class": "yRaY8j"})
actual_price[0].text
# Out:
# '₹1,999'

# %%
discount = card.findAll("div", {"class":"UkUFwK"})
print(discount[0].text)
# Out:
# 87% off

# %%
category = card.findAll("div", {"class":"yiggsN O5Fpg8"})
print(category[0].text)
# Out:
# Hot Deal

# %%
images = []
titles = []
brands = []
actual_prices = []
sales_prices = []
discounts = []
categories = []

for x in range(len(list_of_container)):
    container = list_of_container[x]
    # print(container)
    list_of_content = container.findAll("div", {"class": "_1sdMkc LFEi7Z"})
    # print(len(list_of_content))
    for y in range(len(list_of_content)):
        card = list_of_content[y]
        # print(card)
        image = card.findAll("img", {"class":"_53J4C-"})
        if len(image) == 0:
            images.append(np.nan)
        else:
            images.append(image[0]['src'])
            
        title = card.findAll("a", {"class":"WKTcLC"})
        if len(title) == 0:
            titles.append(np.nan)
        else:
            titles.append(title[0].text)
            
        brand = card.findAll("div", {"class":"syl9yP"})
        if len(brand) == 0:
            brands.append(np.nan)
        else:
            brands.append(brand[0].text)
        
        
        actual_price = card.findAll('div', {"class": "yRaY8j"})
        if len(actual_price) == 0:
            actual_prices.append(np.nan)
        else:
            actual_prices.append(actual_price[0].text)
            
        sales_price = card.findAll('div', {"class": "Nx9bqj"})
        if len(sales_price) == 0:
            sales_prices.append(np.nan)
        else:
            sales_prices.append(sales_price[0].text)
        
        discount = card.findAll("div", {"class":"UkUFwK"})
        if len(discount) == 0:
            discounts.append(np.nan)
        else:
            discounts.append(discount[0].text)
        
        category = card.findAll("div", {"class":"yiggsN O5Fpg8"})
        if len(category) == 0:
            categories.append(np.nan)
        else:
            categories.append(category[0].text)
    
        
        
print(len(images))
print(len(titles))
print(len(brands))
print(len(actual_prices))
print(len(sales_prices))
print(len(discounts))
print(len(categories))
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40

# %%
# Now let's scrape the contents of the whole page:
images = []
titles = []
brands = []
actual_prices = []
sales_prices = []
discounts = []
categories = []
for no in range(1, 20):
    url = f"https://www.flipkart.com/mens-tshirts/pr?sid=clo%2Cash%2Cank%2Cedy&fm=neo%2Fmerchandising&iid=M_aaf81dfd-761f-4f09-936d-7e54b82b4dc3_1_372UD5BXDFYS_MC.IF56C41VGEYS&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Fashion%7EMen%27s%2BTop%2BWear%7EMen%27s%2BT-Shirts_IF56C41VGEYS&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&cid=IF56C41VGEYS&page={no}"
    flipkart = requests.get(url)
    page_html = flipkart.content
    page_soup = soup(page_html, "html.parser")
    list_of_container = page_soup.findAll("div", { "class": "_75nlfW"})
    for x in range(len(list_of_container)):
        container = list_of_container[x]
        # print(container)
        list_of_content = container.findAll("div", {"class": "_1sdMkc LFEi7Z"})
        # print(len(list_of_content))
        for y in range(len(list_of_content)):
            card = list_of_content[y]
            # print(card)
            image = card.findAll("img", {"class":"_53J4C-"})
            if len(image) == 0:
                images.append(np.nan)
            else:
                images.append(image[0]['src'])
                
            title = card.findAll("a", {"class":"WKTcLC"})
            if len(title) == 0:
                titles.append(np.nan)
            else:
                titles.append(title[0].text)
                
            brand = card.findAll("div", {"class":"syl9yP"})
            if len(brand) == 0:
                brands.append(np.nan)
            else:
                brands.append(brand[0].text)
            
            
            actual_price = card.findAll('div', {"class": "yRaY8j"})
            if len(actual_price) == 0:
                actual_prices.append(np.nan)
            else:
                actual_prices.append(actual_price[0].text)
                
            sales_price = card.findAll('div', {"class": "Nx9bqj"})
            if len(sales_price) == 0:
                sales_prices.append(np.nan)
            else:
                sales_prices.append(sales_price[0].text)
            
            discount = card.findAll("div", {"class":"UkUFwK"})
            if len(discount) == 0:
                discounts.append(np.nan)
            else:
                discounts.append(discount[0].text)
            
            category = card.findAll("div", {"class":"yiggsN O5Fpg8"})
            if len(category) == 0:
                categories.append(np.nan)
            else:
                categories.append(category[0].text)
        
        
        
print(len(images))
print(len(titles))
print(len(brands))
print(len(actual_prices))
print(len(sales_prices))
print(len(discounts))
print(len(categories))
# Out:
# 760
# 760
# 760
# 760
# 760
# 760
# 760

# %%
df = pd.DataFrame({"Images":images, 
                   "Titles":titles,
                   "Brands":brands,
                   "Actual Prices":actual_prices,
                   "Sales Prices":sales_prices,
                   "Discounts":discounts,
                   "Categories":categories
                  })
# df['Categories'].unique()
df.head()
# df.info()
# Out:
#                                               Images  \
# 0  https://rukminim2.flixcart.com/image/612/612/x...
# 1  https://rukminim2.flixcart.com/image/612/612/x...
# 2  https://rukminim2.flixcart.com/image/612/612/x...
# 3  https://rukminim2.flixcart.com/image/612/612/x...
# 4  https://rukminim2.flixcart.com/image/612/612/x...
#
#                                               Titles             Brands  \
# 0  Men Solid Mandarin Collar Cotton Blend Dark Gr...              TRIPR
# 1  Men Striped Round Neck Cotton Blend Blue, Blac...               AUSK
# 2  Men Solid Round Neck Polyester Light Green T-S...             VeBNoR
# 3     Men Solid Polo Neck Cotton Blend White T-Shirt  Fashion And Youth
# 4  Men Checkered Polo Neck Cotton Blend Maroon, W...               AUSK
#
#   Actual Prices Sales Prices Discounts                   Categories
# 0        ₹1,999         ₹253   87% off                     Hot Deal
# 1        ₹1,499         ₹262   82% off  Buy 2 items, save extra ₹30
# 2          ₹999         ₹257   74% off                     Hot Deal
# 3        ₹1,499         ₹347   76% off                Only few left
# 4        ₹1,499         ₹330   77% off                     Hot Deal

# %%
df.to_csv("flipkart_mens_tshirts.csv", index=False)

# %%
from bs4 import BeautifulSoup as soup
import requests

jiji = requests.get("https://jiji.ng/cars?filter_attr_1_make=Mercedes-Benz")
page_html = jiji.content

# %%
page_soup = soup(page_html, "html.parser")

# %%
# Now let's see how many HTML containers are present in this link:
containers = page_soup.findAll("div", { "class": "masonry-column"})
len(containers)
# Out:
# 3

# %%
# print div for the first container
# print(soup.prettify(containers[0]))
containers[0]
# Out:
# <div class="masonry-column" style="width:33.333333333333336%;"><div data-column="0"><!--[--><div class="masonry-item" style=""><!--[--><!-- --><div class="b-list-advert__gallery__item js-advert-list-item"><a class="b-list-advert-base b-list-advert-base--gallery qa-advert-list-item" href="/amuwo-odofin/cars/mercedes-benz-c300-sport-sedan-rwd-2-0l-4cyl-7a-2016-black-9YnxQflkCyiYcgZiPWVwZw6P.html" style=""><div class="b-list-advert-base__img__wrapper b-list-advert-base__img__wrapper--one-image"><!--[--><!--[--><div class="b-list-advert-base__img js-list-advert-base-img" style="padding-bottom:75%;"><!-- --><picture class="h-flex-center h-width-100p h-height-100p h-overflow-hidden"><!--[--><source srcset="https://pictures-nigeria.jijistatic.net/171611727_MzAwLTIyNS1hYjIwY2ZiOTM2.webp 1x" type="image/webp"/><!--]--><img alt="Photo - Mercedes-Benz C300 Sport Sedan RWD (2.0L 4cyl 7A) 2016 Black" class="" data-nuxt-pic="" loading="eager" onerror="this.setAttribute('data-error', 1)" src="https://pictures-nigeria.jijistatic.net/171611727_MzAwLTIyNS1hYjIwY2ZiOTM2.webp" srcset="https://pictures-nigeria.jijistatic.net/171611727_MzAwLTIyNS1hYjIwY2ZiOTM2.webp 1x" style="height:100%;width:100%;"/></picture></div><!--]--><!--]--><div class="b-list-advert-base__labels"><!--[--><!--]--></div><!-- --></div><div class="b-list-advert-base__data"><div class="b-list-advert-base__data__inner"><div class="b-list-advert-base__data__header"><div class="b-list-advert-base__data__price"><div class="b-list-advert__price h-mt-3"><div class="b-list-advert__price-base"><div class="qa-advert-price">₦ 24,000,000</div><!-- --></div><!--[--><!--]--></div><!-- --></div><div class="b-list-advert-base__data__title"><div class="qa-advert-list-item-title b-list-advert-base__item-title"><!--[--><!--]--><div class="b-advert-title-inner qa-advert-title b-advert-title-inner--div">Mercedes-Benz C300 Sport Sedan RWD (2.0L 4cyl 7A) 2016 Black</div></div></div></div><div class="b-list-advert-base__body"><div class="b-list-advert-base__description"><div class="b-list-advert-base__description-text">Foreign Used Mercedes Benz C300 2016 full options with thumbstart, panoramic roof. It's not 4matic.</div></div><div class="b-list-advert-base__attrs"><div class="b-list-advert-base__item-attr__wrapper"><!-- --><!-- --><!--[--><div class="b-list-advert-base__item-attr">Foreign Used <!-- --></div><div class="b-list-advert-base__item-attr">Automatic <!-- --></div><!--]--></div></div><div class="b-list-advert-base__bottom-wrapper"><div class="b-list-advert-base__location"><!-- --></div><div class="b-list-advert-base__ps-logo"><div class="b-static-image" style="height:16px;width:16px;"><img alt="diamond" class="icon" height="16px" src="https://assets.jijistatic.net/static/img/premium-landing/diamond.svg" style="" width="16px"/></div></div></div></div></div></div></a></div><!-- --><!--]--></div><div class="masonry-item" style=""><!--[--><!-- --><div class="b-list-advert__gallery__item js-advert-list-item"><a class="b-list-advert-base b-list-advert-base--vip b-list-advert-base--gallery qa-advert-list-item" href="/lekki/cars/mercedes-benz-c300-2015-silver-q2c9ReO3xFyEGNMBErBaJJdB.html" style="border:2px solid #00B53F;"><div class="b-list-advert-base__img__wrapper b-list-advert-base__img__wrapper--one-image"><!--[--><!--[--><div class="b-list-advert-base__img js-list-advert-base-img" style="padding-bottom:133.33333333333331%;"><!-- --><picture class="h-flex-center h-width-100p h-height-100p h-overflow-hidden"><!--[--><source srcset="https://pictures-nigeria.jijistatic.net/166575256_MzAwLTQwMC05YTM4MjAyNTEy.webp 1x" type="image/webp"/><!--]--><img alt="Photo - Mercedes-Benz C300 2015 Silver" class="" data-nuxt-pic="" loading="lazy" onerror="this.setAttribute('data-error', 1)" src="https://pictures-nigeria.jijistatic.net/166575256_MzAwLTQwMC05YTM4MjAyNTEy.webp" srcset="https://pictures-nigeria.jijistatic.net/166575256_MzAwLTQwMC05YTM4MjAyNTEy.webp 1x" style="height:100%;width:100%;"/></picture></ ...
# Direct owner
# % accident free
# Location ajah</div></div><div class="b-list-advert-base__attrs"><div class="b-list-advert-base__item-attr__wrapper"><!-- --><!-- --><!--[--><div class="b-list-advert-base__item-attr">Foreign Used <!-- --></div><div class="b-list-advert-base__item-attr">Automatic <!-- --></div><!--]--></div></div><div class="b-list-advert-base__bottom-wrapper"><div class="b-list-advert-base__location"><!-- --></div><div class="b-list-advert-base__ps-logo"><div class="b-static-image" style="height:16px;width:16px;"><img alt="diamond" class="icon" height="16px" src="https://assets.jijistatic.net/static/img/premium-landing/diamond.svg" style="" width="16px"/></div></div></div></div></div></div></a></div><!-- --><!--]--></div><div class="masonry-item" style=""><!--[--><!-- --><div class="b-list-advert__gallery__item js-advert-list-item"><a class="b-list-advert-base b-list-advert-base--gallery qa-advert-list-item" href="/lekki/cars/mercedes-benz-gla-250-2015-red-tVjVMOsJZH9Cp98PcJlYBqpl.html" style="border:2px solid #FEA03C;"><div class="b-list-advert-base__img__wrapper b-list-advert-base__img__wrapper--one-image"><!--[--><!--[--><div class="b-list-advert-base__img js-list-advert-base-img" style="padding-bottom:133.33333333333331%;"><!-- --><picture class="h-flex-center h-width-100p h-height-100p h-overflow-hidden"><!--[--><source srcset="https://pictures-nigeria.jijistatic.net/168852242_MzAwLTQwMC02YmI4ZmU3ZTBm.webp 1x" type="image/webp"/><!--]--><img alt="Photo - Mercedes-Benz GLA 250 2015 Red" class="" data-nuxt-pic="" loading="lazy" onerror="this.setAttribute('data-error', 1)" src="https://pictures-nigeria.jijistatic.net/168852242_MzAwLTQwMC02YmI4ZmU3ZTBm.webp" srcset="https://pictures-nigeria.jijistatic.net/168852242_MzAwLTQwMC02YmI4ZmU3ZTBm.webp 1x" style="height:100%;width:100%;"/></picture></div><!--]--><!--]--><div class="b-list-advert-base__labels"><!--[--><!--]--></div><!-- --></div><div class="b-list-advert-base__data"><div class="b-list-advert-base__data__inner"><div class="b-list-advert-base__data__header"><div class="b-list-advert-base__data__price"><div class="b-list-advert__price h-mt-3"><div class="b-list-advert__price-base"><div class="qa-advert-price">₦ 24,000,000</div><!-- --></div><!--[--><!--]--></div><!-- --></div><div class="b-list-advert-base__data__title"><div class="qa-advert-list-item-title b-list-advert-base__item-title"><!--[--><!--]--><div class="b-advert-title-inner qa-advert-title b-advert-title-inner--div">Mercedes-Benz GLA 250 2015 Red</div></div></div></div><div class="b-list-advert-base__body"><div class="b-list-advert-base__description"><div class="b-list-advert-base__description-text">New imported arrival
# Gla mercedes 2015 model
# 4 door
# Massage seat
# Noting to fix all good.
# Orchid...</div></div><div class="b-list-advert-base__attrs"><div class="b-list-advert-base__item-attr__wrapper"><!-- --><!-- --><!--[--><div class="b-list-advert-base__item-attr">Foreign Used <!-- --></div><div class="b-list-advert-base__item-attr">Automatic <!-- --></div><!--]--></div></div><div class="b-list-advert-base__bottom-wrapper"><div class="b-list-advert-base__location"><!-- --></div><div class="b-list-advert-base__ps-logo"><div class="b-static-image" style="height:16px;width:16px;"><img alt="premium" class="icon" height="16px" src="https://assets.jijistatic.net/static/img/premium-landing/premium.svg" style="" width="16px"/></div></div></div></div></div></div></a></div><!-- --><!--]--></div><div class="masonry-item" style=""><!--[--><!-- --><div class="b-list-advert__gallery__item js-advert-list-item"><a class="b-list-advert-base b-list-advert-base--gallery qa-advert-list-item" href="/apapa/cars/mercedes-benz-m-class-ml-550-4matic-2013-black-zDsZfvEVCQsvlvZLtjDX9tZb.html" style=""><div class="b-list-advert-base__img__wrapper b-list-advert-base__img__wrapper--one-image"><!--[--><!--[--><div class="b-list-advert-base__img js-list-advert-base-img" style="padding-bottom:75%;"><!-- --><picture class="h-flex-center h-width-100p h-height-100p h-overflow-hidden"><!--[--><source srcset="https://pictures-nigeria.jijistatic.net/151779168_MzAwLTIyNS0xMTFiNGU4MjE3.webp 1x" type="image/webp"/><!--]--><img alt="Photo - Mercedes-Benz M Class ML 550 4Matic 2013 Black" class="" data-nuxt-pic="" loading="lazy" onerror="this.setAttribute('data-error', 1)" src="https://pictures-nigeria.jijistatic.net/151779168_MzAwLTIyNS0xMTFiNGU4MjE3.webp" srcset="https://pictures-nigeria.jijistatic.net/151779168_MzAwLTIyNS0xMTFiNGU4MjE3.webp 1x" style="height:100%;width:100%;"/></picture></div><!--]--><!--]--><!-- --><!-- --></div><div class="b-list-advert-base__data"><div class="b-list-advert-base__data__inner"><div class="b-list-advert-base__data__header"><div class="b-list-advert-base__data__price"><div class="b-list-advert__price h-mt-3"><div class="b-list-advert__price-base"><div class="qa-advert-price">₦ 31,500,000</div><!-- --></div><!--[--><!--]--></div><!-- --></div><div class="b-list-advert-base__data__title"><div class="qa-advert-list-item-title b-list-advert-base__item-title"><!--[--><!--]--><div class="b-advert-title-inner qa-advert-title b-advert-title-inner--div">Mercedes-Benz M Class ML 550 4Matic 2013 Black</div></div></div></div><div class="b-list-advert-base__body"><div class="b-list-advert-base__description"><div class="b-list-advert-base__description-text">Tincan clearing,duty paid, navigation system, reverse camera, Bluetooth,alloy wheel,v8...</div></div><div class="b-list-advert-base__attrs"><div class="b-list-advert-base__item-attr__wrapper"><!-- --><!-- --><!--[--><div class="b-list-advert-base__item-attr">Foreign Used <!-- --></div><div class="b-list-advert-base__item-attr">Automatic <!-- --></div><!--]--></div></div><div class="b-list-advert-base__bottom-wrapper"><div class="b-list-advert-base__location"><!-- --></div><div class="b-list-advert-base__ps-logo"><div class="b-static-image" style="height:16px;width:16px;"><img alt="enterprise" class="icon" height="16px" src="https://assets.jijistatic.net/static/img/premium-landing/enterprise.svg" style="" width="16px"/></div></div></div></div></div></div></a></div><!-- --><!--]--></div><div class="masonry-item" style=""><!--[--><!-- --><div class="b-list-advert__gallery__item js-advert-list-item"><a class="b-list-advert-base b-list-advert-base--gallery qa-advert-list-item" href="/apapa/cars/mercedes-benz-gle-class-amg-gle-43-4matic-2018-silver-cpwEDpwmkmSmgftKq2UWzQXd.html" style=""><div class="b-list-advert-base__img__wrapper b-list-advert-base__img__wrapper--one-image"><!--[--><!--[--><div class="b-list-advert-base__img js-list-advert-base-img" style="padding-bottom:75%;"><!-- --><picture class="h-flex-center h-width-100p h-height-100p h-overflow-hidden"><!--[--><source srcset=" ...
# Panoramic sunroof,
# Pure Accident free,
# Clean Interior,
# No...</div></div><div class="b-list-advert-base__attrs"><div class="b-list-advert-base__item-attr__wrapper"><!-- --><!-- --><!--[--><div class="b-list-advert-base__item-attr">Foreign Used <!-- --></div><div class="b-list-advert-base__item-attr">Automatic <!-- --></div><!--]--></div></div><div class="b-list-advert-base__bottom-wrapper"><div class="b-list-advert-base__location"><!-- --></div><div class="b-list-advert-base__ps-logo"><div class="b-static-image" style="height:16px;width:16px;"><img alt="enterprise" class="icon" height="16px" src="https://assets.jijistatic.net/static/img/premium-landing/enterprise.svg" style="" width="16px"/></div></div></div></div></div></div></a></div><!-- --><!--]--></div><div class="masonry-item" style=""><!--[--><!-- --><div class="b-list-advert__gallery__item js-advert-list-item"><a class="b-list-advert-base b-list-advert-base--gallery qa-advert-list-item" href="/apapa/cars/mercedes-benz-glk-class-350-4matic-2010-white-4V6a2D81LExgRjRLe4tTwY3C.html" style="border:2px solid #00B53F;"><div class="b-list-advert-base__img__wrapper b-list-advert-base__img__wrapper--one-image"><!--[--><!--[--><div class="b-list-advert-base__img js-list-advert-base-img" style="padding-bottom:75%;"><!-- --><picture class="h-flex-center h-width-100p h-height-100p h-overflow-hidden"><!--[--><source srcset="https://pictures-nigeria.jijistatic.net/164768295_MzAwLTIyNS02OThlNjFhMWY5.webp 1x" type="image/webp"/><!--]--><img alt="Photo - Mercedes-Benz GLK-Class 350 4MATIC 2010 White" class="" data-nuxt-pic="" loading="lazy" onerror="this.setAttribute('data-error', 1)" src="https://pictures-nigeria.jijistatic.net/164768295_MzAwLTIyNS02OThlNjFhMWY5.webp" srcset="https://pictures-nigeria.jijistatic.net/164768295_MzAwLTIyNS02OThlNjFhMWY5.webp 1x" style="height:100%;width:100%;"/></picture></div><!--]--><!--]--><!-- --><div class="b-list-advert-base__pkg-label">ENTERPRISE</div></div><div class="b-list-advert-base__data"><div class="b-list-advert-base__data__inner"><div class="b-list-advert-base__data__header"><div class="b-list-advert-base__data__price"><div class="b-list-advert__price h-mt-3"><div class="b-list-advert__price-base"><div class="qa-advert-price">₦ 20,000,000</div><!-- --></div><!--[--><!--]--></div><!-- --></div><div class="b-list-advert-base__data__title"><div class="qa-advert-list-item-title b-list-advert-base__item-title"><!--[--><!--]--><div class="b-advert-title-inner qa-advert-title b-advert-title-inner--div">Mercedes-Benz GLK-Class 350 4MATIC 2010 White</div></div></div></div><div class="b-list-advert-base__body"><div class="b-list-advert-base__description"><div class="b-list-advert-base__description-text">Mercedez Benz
# GLK350
# Accident free
# Full options
# No dent
# AC working fine
# Fully duty paid
# Navigation...</div></div><div class="b-list-advert-base__attrs"><div class="b-list-advert-base__item-attr__wrapper"><!-- --><!-- --><!--[--><div class="b-list-advert-base__item-attr">Foreign Used <!-- --></div><div class="b-list-advert-base__item-attr">Automatic <!-- --></div><!--]--></div></div><div class="b-list-advert-base__bottom-wrapper"><div class="b-list-advert-base__location"><!-- --></div><div class="b-list-advert-base__ps-logo"><div class="b-static-image" style="height:16px;width:16px;"><img alt="enterprise" class="icon" height="16px" src="https://assets.jijistatic.net/static/img/premium-landing/enterprise.svg" style="" width="16px"/></div></div></div></div></div></div></a></div><!-- --><!--]--></div><!--]--></div></div>

# %%
# Let us crap information for one product first
content = containers[0]
content = page_soup.findAll("div", { "class": "masonry-item"})
len(content)
# Out:
# 20

# %%
# Let get the name of the product
card = content[11]
image = card.findAll('img')
image[1]['src']
# Out:
# 'https://assets.jijistatic.net/static/img/premium-landing/premium.svg'

# %%
price = card.findAll('div', {'class': 'qa-advert-price'})
# labels[0].findAll('div', {'class': 'b-list-advert-base__label'})
price[0].text
# Out:
# '₦ 4,500,000'

# %%
title = card.findAll('div', {'class': 'b-advert-title-inner qa-advert-title b-advert-title-inner--div'})
title[0].text
# Out:
# 'Mercedes-Benz C180 2000 Matt Black'

# %%
description = card.findAll('div', {'class': 'b-list-advert-base__description-text'})
description[0].text
# Out:
# 'The car is good as direct no any fult of any kind sound engine and gear smooth movement and geat...'

# %%
attr = card.findAll('div', {'class': 'b-list-advert-base__item-attr'})
attr1 = attr[0].text
attr2 = attr[1].text

print(attr1, attr2)
# Out:
# Local Used  Automatic

# %%
# 
location = card.findAll('div', {'class': 'b-list-advert-base__bottom-wrapper'})
location[0].findAll('div', {'class': 'b-list-advert-base__location'})
loc = location[0]
loc
loc.findAll('div', {'class': 'b-list-advert-base__location'})
# Out:
# ''

# %%
# Now that we are able to extract details for one product, let's now loop for other products
products = []
pricing = []
rating = []

for container in containers:
    for val in container.findAll("div", {"class": "_4ddWXP _3BCh3_"}):
        if len(val)!=0:
           #     append product name for each
            products.append(val.findAll("a", {"class": "_2rpwqI"})[0]['title'])
            print(val.findAll("a", {"class": "_2rpwqI"})[0]['title'])
            #     append product price for each
            pricing.append(val.findAll("div", {"class": "_30jeq3"})[0].text)
            print(val.findAll("div", {"class": "_30jeq3"})[0].text)
            #     append product rating for each
            rating_val = val.findAll("span", {"class": "_2_R_DZ"})
            if len(rating_val)!=0:
                rating.append(rating_val[0].text)
                print(rating_val[0].text)
            else:
                rating.append(np.nan)

# %%
df = pd.DataFrame({"Product_Name":products, "Pricing":pricing, "Rating":rating})
df.to_csv("tv_data.csv")
tv_data = pd.read_csv("tv_data.csv")
tv_data.head()

# %% [markdown]
# # Scrapping JavaScript Rendering page
# Many modern websites are dynamic, in which the content is loaded and populated using client JavaScript. Therefore, some extra setups are required in order to scrape data from JavaScript webpages.
# In this class, you’ll learn how to scrape contents from a JavaScript webpage using Selenium, BeautifulSoup, and Pandas.
# In order to run this example, you need to configure your system with the following steps.
# If you have pip on your system, you can simply install these libraries by
#
#
#     pip install selenium==3.8.0
#     pip install beautifulsoup4
#     pip install pandas
#
# # Download Selenium web driver
# Selenium requires a driver to interface with the chosen browser. For example, Chrome requires ChromeDriver, which needs to be installed before running the example.
# To install ChromeDriver, you should:
# download the same version ChromeDriver as the Chrome you are using.
# place the ChromeDriver executable in your PATH, for example, place it in /usr/bin or /usr/local/bin.
# You will get a WebDriverException error if you don’t have a proper Selenium web driver in your PATH.
#
# Note: Selenium also have suport for other browsers e.g Firefox etc. To use any of this drivers, you must download their web driver by following the same setup as chrome above.

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.32.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\welcome\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\welcome\anaconda3\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\welcome\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\welcome\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sortedcontainers in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\welcome\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\welcome\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\welcome\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\welcome\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.32.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.4 MB 217.7 kB/s eta 0:00:41
#    -- ------------------------------------- 0.5/9.4 MB 217.7 kB/s eta 0:00:41
#    -- ------------------------------------- 0.5/9.4 MB 217.7 kB/s eta 0:00:41
#    -- ------------------------------------- 0.5/9.4 MB 217.7 kB/s eta 0:00:41
#    -- ------------------------------------- 0.5/9.4 MB 217.7 kB/s eta 0:00:41
#    -- ------------------------------------- 0.5/9.4 MB 217.7 kB/s eta 0:00:41
#    -- ------------------------------------- 0.5/9.4 MB 217.7 kB/s eta 0:00:41
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    --- ------------------------------------ 0.8/9.4 MB 189.5 kB/s eta 0:00:46
#    ---- ----------------------------------- 1.0/9.4 MB 152.1 kB/s eta 0:00:55
#    ---- ----------------------------------- 1.0/9.4 MB 152.1 kB/s eta 0:00:55
#    ---- ----------------------------------- 1.0/9.4 MB 152.1 kB/s eta 0:00:55
#    ---- ----------------------------------- 1.0/9.4 MB 152.1 kB/s eta 0:00:55
#    ----- ---------------------------------- 1.3/9.4 MB 174.8 kB/s eta 0:00:47
#    ----- ---------------------------------- 1.3/9.4 MB 174.8 kB/s eta 0:00:47
#    ------ --------------------------------- 1.6/9.4 MB 208.1 kB/s eta 0:00:38
#    ------- -------------------------------- 1.8/9.4 MB 236.8 kB/s eta 0:00:32
#    ------- -------------------------------- 1.8/9.4 MB 236.8 kB/s eta 0:00:32
#    -------- ------------------------------- 2.1/9.4 MB 263.9 kB/s eta 0:00:28
#    -------- ------------------------------- 2.1/9.4 MB 263.9 kB/s eta 0:00:28
#    -------- ------------------------------- 2.1/9.4 MB 263.9 kB/s eta 0:00:28
#    -------- ------------------------------- 2.1/9.4 MB 263.9 kB/s eta 0:00:28
#    -------- ------------------------------- 2.1/9.4 MB 263.9 kB/s eta 0:00:28
#    -------- ------------------------------- 2.1/9.4 MB 263.9 kB/s eta 0:00:28
#    ---------- ----------------------------- 2.4/9.4 MB 253.2 kB/s eta 0:00:28
#    ----------- ---------------------------- 2.6/9.4 MB 281.2 kB/s eta 0:00:25
#    ------------ --------------------------- 2.9/9.4 MB 301.7 kB/s eta 0:00:22
#    ------------- -------------------------- 3.1/9.4 MB 323.2 kB/s eta 0:00:20
#    -------------- ------------------------- 3.4/9.4 MB 341.2 kB/s eta 0:00:18
#    --------------- ------------------------ 3.7/9.4 MB 361.1 kB/s eta 0:00:16
#    --------------- ------------------------ 3.7/9.4 MB 361.1 kB/s eta 0:00:16
#    ---------------- ----------------------- 3.9/9.4 MB 377.0 kB/s eta 0:00:15
#    ----------------- ---------------------- 4.2/9.4 MB 397.5 kB/s eta 0:00:14
#    -------------------- ------------------- 4.7/9.4 MB 432.1 kB/s eta 0:00:11
#    --------------------- ------------------ 5.0/9.4 MB 448.7 kB/s eta 0:00:10
#    --------------------- ------------------ 5.0/9.4 MB 448.7 kB/s eta 0:00:10
#    ---------------------- ----------------- 5.2/9.4 MB 460.6 kB/s eta 0:00:09
#    ----------------------- ---------------- 5.5/9.4 MB 476.6 kB/s eta 0:00:09
#    ------------------------ --------------- 5.8/9.4 MB 492.0 kB/s eta 0:00:08
#    ------------------------- -------------- 6.0/9.4 MB 505.6 kB/s eta 0:00:07
#    -------------------------- ------------- 6.3/9.4 MB 515.1 kB/s eta 0:00:06
#    --------------------------- ------------ 6.6/9.4 MB 529.1 kB/s eta 0:00:06
#    ----------------------------- ---------- 6.8/9.4 MB 539.8 kB/s eta 0:00:05
#    ------------------------------ --------- 7.1/9.4 MB 552.1 kB/s eta 0:00:05
#    ------------------------------ --------- 7.1/9.4 MB 552.1 kB/s eta 0:00:05
#    ------------------------------ --------- 7.1/9.4 MB 552.1 kB/s eta 0:00:05
#    ------------------------------ --------- 7.1/9.4 MB 552.1 kB/s eta 0:00:05
#    ------------------------------- -------- 7.3/9.4 MB 534.2 kB/s eta 0:00:04
#    ------------------------------- -------- 7.3/9.4 MB 534.2 kB/s eta 0:00:04
#    -------------------------------- ------- 7.6/9.4 MB 539.3 kB/s eta 0:00:04
#    --------------------------------- ------ 7.9/9.4 MB 546.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.1/9.4 MB 556.1 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.1/9.4 MB 556.1 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.1/9.4 MB 556.1 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.1/9.4 MB 556.1 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.1/9.4 MB 556.1 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.4/9.4 MB 537.8 kB/s eta 0:00:02
#    ------------------------------------ --- 8.7/9.4 MB 546.1 kB/s eta 0:00:02
#    ------------------------------------ --- 8.7/9.4 MB 546.1 kB/s eta 0:00:02
#    -------------------------------------- - 8.9/9.4 MB 548.7 kB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.4 MB 548.7 kB/s eta 0:00:01
#    ---------------------------------------  9.2/9.4 MB 552.2 kB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 552.0 kB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-25.3.0 outcome-1.3.0.post0 selenium-4.32.0 trio-0.30.0 trio-websocket-0.12.2 wsproto-1.2.0

# %%
from selenium import webdriver
import time
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup as soup

# driver = webdriver.Chrome()
# driver.get("https://jiji.ng/cars?filter_attr_1_make=Mercedes-Benz")
# time.sleep(3)
# html_source = driver.page_source
# driver.quit()


# Running selenium in headless mode i.e while executing it would'nt display the web browser
# options = Options()
# options.add_argument("headless")

# driver = webdriver.Chrome(options=options)
# driver.get("https://jiji.ng/cars?filter_attr_1_make=Mercedes-Benz")
# time.sleep(3)
# html_source = driver.page_source
# driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.edge.options import Options


#Executing in head mode i.e while executing it would display the web browser
driver = webdriver.Edge()
driver.get('https://jiji.ng/cars')
html_source = driver.page_source 
driver.quit()


#Executing in headless mode i.e while executing it would'nt display the web browser
# options = Options()
# options.add_argument("headless")

# driver = webdriver.Edge(options = options)
# driver.get('https://jiji.ng/cars')
# html_source = driver.page_source 
# driver.quit()

# %%
page_soup = soup(html_source,'html.parser')
# page_soup
list_of_column = page_soup.findAll("div", {"class": "masonry-column"})
len(list_of_column)
# Out:
# 3

# %%
column = list_of_column[0]
list_of_item = column.findAll("div", {"class": "masonry-item"})
len(list_of_item)
# Out:
# 7

# %%
item = list_of_item[0]
image = item.findAll('img')
image[0]['src']
# Out:
# 'https://pictures-nigeria.jijistatic.net/161460989_MzAwLTMzNi1kMjE2NzJmM2E1.webp'

# %%
labels = item.findAll('div', {'class': 'b-list-advert-base__label'})
label1 = labels[0].text.strip()
label2 = labels[1].text.strip()
label1, label2
# Out:
# ('Popular', 'Quick reply')

# %%
price = item.findAll('div', {'class', 'qa-advert-price'})
price[0].text
# Out:
# '₦ 72,000,000'

# %%
title = item.findAll('div', {'class': 'b-advert-title-inner qa-advert-title b-advert-title-inner--div'})
title[0].text
# Out:
# 'Mercedes-Benz GLE-Class 2016 Red'

# %%
description = item.findAll('div', {'class': 'b-list-advert-base__description-text'})
description[0].text
# Out:
# '2016 gle450 \nToks \nFresh entry \nSoft closing doors \nRear ac vent'

# %%
attr1 = item.findAll('div', {'class': 'b-list-advert-base__item-attr'})
attr1[0].text.strip()
# Out:
# 'Foreign Used'

# %%
attr2 = item.findAll('div', {'class': 'b-list-advert-base__item-attr'})
attr2[1].text.strip()
# Out:
# 'Automatic'

# %% [markdown]
# # WEBSCRAPPING USING APIs

# %% [markdown]
# # Wikipedia Scraping
# Wikipedia is one of those largest platforms which provides almost every information for free. From your kindergarten till today, you must have visited this platform atleast once to get any information from school presentations to professional research, Wikipedia helps everybody.
# Unlike other sources of information websites, Wikipedia has its API to scrape data from its articles. Python being a general-purpose programming language provides packages for almost every task. So we have a package named as wikipedia for Python which we can use to scrape Wikipedia articles using Python. To scrape useful information from Wikipedia, you need to install a package named as wikipedia, which can be easily
# installed using the pip command- pip install wikipedia.

# %%
# import wilipedia as wiki
import wikipedia as wiki
wiki.__version__

# %%
# To explain the use of this package, I will scrape information based on Python. So let's start with the task to scrape
# Wikipedia articles. The code below will get all the search suggestions of our input. In our case, it will return the 
# search suggestions of Python:
print(wiki.search("python"))

# %%
# Now let's see will the search engine on Wikipedia suggest us python if we will type only some alphabets of its spelling:
print(wiki.suggest("Pyth"))

# %%
# Yes, it works, now let's have a look how we can get the summary of an article on Wikipedia:
print(wiki.summary("Python (programming language)"))

# %%
# If you want to read the summary in another language other than English, we can also do that. I will get the same summary
# above in the French language:
wiki.set_lang("fr")
print(wiki.summary("Python (programming language)"))

# %%
# Now let's change the language back to English and have a look at some more insights from the article. Here I will 
# scrape all the information we will get if we will read about python on Wikipedia:
wiki.set_lang("en")
p = wiki.page("Python (programming language)")
p

# %%
# To get the Title:
print(p.title)

# %%
# To get the url of the article:
print(p.url)

# %%
# To scrape the full article:
print(p.content)

# %%
# To get all the images in the article:
print(p.images)

# %%
# And to get all the referals used by Wikipedia in the article:
p.links

# %% [markdown]
# # Twitter Scraping
# One of the hot topics in data science is social media analytics. People love these analyzes and interest them because everyone knows this world. Most of our time is spent on Twitter, Instagram, Facebook, and some other social media apps. The use of social media analysis is mostly used in the tasks of relationship analysis. With not only scraping twitter with python, but I will also do some relationship analysis based on our scrapped data.
#
# Scraping Twitter with Python
# Now, let's start with our task. In this task of scraping twitter with python, we need to install a package known as twint, which can be easily installed by using the pip command in your terminal - pip install twint.

# %%
import twint
import pandas as pd
from collections import Counter
import nest_asyncio

nest_asyncio.apply()

# %%
c = twint.Config()
c.Search = "lockdown"
c.Limit = 5000
c.Store_csv = True
c.Output = 'lockdown_tweet_data.csv'
twint.run.Search(c)

# %%
# c = twint.Config()
# c.Username = 'segalink'
# twint.run.Followers(c)

c = twint.Config()
c.Username = "segalink"
c.Limit = 500
c.Store_csv = True
c.User_full = True
c.Output = "users.csv"
twint.run.Followers(c)

# %%
# After importing the necessary libraries, now we need to start by creating a user list consisting of Twitter accounts. 
# We will analyze the relationships between the Twitter accounts of these people that I will add in the list below:

users = [
    'Elonmusk',
    'Arsenal',
    'Leereports',
    'segalink',
]

# %%
# Scraping Twitter with Python and Analyzing Relationships
# Now let's start by scraping Twitter with python and to analyze the relationships between all the Twitter accounts in our
# list above, I'll write a function named get_followings which will send a request to the twint library with a username. 
# This function will return a list of users that our input user follows:

def get_followings(username):

    c = twint.Config()
    c.Username = username
    c.Pandas = True

    twint.run.Following(c)
    list_of_followings = twint.storage.panda.Follow_df

    return list_of_followings['following'][username]

# %%
# The for loop below will create two variables, as sometimes we get index error when Twitter does not respond to our 
# request. For such cases, I added an exception to the code to ignore these users:

followings = {}
following_list = []
for person in users:
    print('#####\nStarting: ' + person + '\n#####')
    try:
        followings[person] = get_followings(person)
        following_list = following_list + followings[person]
    except KeyError:
        print('IndexError')

# %%
# After getting all of the following lists, we can just calculate the most common values in the following_list variable 
# to get the most popular accounts among our users. To get the 10 most followed accounts, we will use the Counter function
# of the collection library:

Counter(following_list).most_common(10)

# %%
# What if we want to see who's following who in our user group? To study it, I wrote a for loop that checks if anyone among 
# the users is in the following list of another person. As a result, it creates a list dictionary displaying the following
# states represented by True and False:

follow_relations ={}
for following_user in followings.keys():
    follow_relation_list = []
    for followed_user in followings.keys():
        if followed_user in followings[following_user]:
            follow_relation_list.append(True)
        else:
            follow_relation_list.append(False)
    follow_relations[following_user] = follow_relation_list

# %%
# In the code below, the resulting dictionary is transformed into a pandas dataframe for a more user-friendly 
# visualization. The rows of the dataframe show the users who follow, while the columns show the users who are followed:

following_df = pd.DataFrame.from_dict(follow_relations, 
                                      orient='index', columns=followings.keys())
following_df

# %% [markdown]
# # Instagram Scraping
# First of all, if you are learning Data Science then scraping Instagram will help you in getting the new trends of businesses, so that you can generate more leads and can reach out for your new potential customers.
# To scrap Instagram, we will use a library know as instaloader which provides us with an API for scraping Instagram. You can install this library by using the pip method in your terminal - pip install instaloader. Now If you have installed this package then let's get started with the task.

# %%
# Import the module
import instaloader

# %%
# Create an instance of Instaloader class
bot = instaloader.Instaloader()

# Load a profile from an Instagram handle
profile = instaloader.Profile.from_username(bot.context, 'nigerianbulletin')
print(type(profile))
print(profile)

# %%
# Now let's see how we can extract some valuable information from an Instagram profile:

print("Username: ", profile.username)
print("User ID: ", profile.userid)
print("Number of Posts: ", profile.mediacount)
print("Followers: ", profile.followers)
print("Followees: ", profile.followees)
print("Bio: ", profile.biography,profile.external_url)

# %%
# Login with username and password in the script
profile=bot.login(user="arisedamilare",passwd="")
print(profile)

# %%
# Interactive login on terminal
profile = bot.interactive_login("arisedamilare") # Asks for password in the terminal
print(profile)

# %%
# Scraping your followers and followees will help you in getting a list of their usernames, which you will require to do 
# when you will work in a professional environment in the data science field:

# Retrieve the usernames of all followers
followers = [follower.username for follower in profile.get_followers()]
print(followers)
print(len(followers))

# %%
# Retrieve the usernames of all followees
followees = [followee.username for followee in profile.get_followees()]
print(followees)

# %%
# Getting posts from any profile is easy in python. We just need to use get_posts(). I will use this method on the
# profile of someone else. To download each post, we need to loop over the generator object using .download_post() method.
# Now let's  go through this:

# Load a new profile
profile = instaloader.Profile.from_username(bot.context, 'nigerianbulletin')

# Get all posts in a generator object
posts = profile.get_posts()
posts

# %%
# Iterate and download
# It will save the post folder by creating its directory. In each folder, you will see the actual content of the posts of
# the profile like a video or images.

for index, post in enumerate(posts, 1):
    bot.download_post(post, target=f"{profile.username}_{index}")

# %% [markdown]
# # Youtube Scraping
# For the task of scraping youtube with python, we have a package known as pytube3, which can be easily installed by using the pip command - pip install pytube3. Now let's get started with the task of scraping youtube by importing this package:

# %%
# You will notice that we have and installed pytube3 by using the pip command, but we are importing pytube and not pytube3.
# To eliminate confusion, pytube3 is also imported by writing only pytube. We don't import it by writing as pytube3.
from pytube import YouTube

# %%
# Our next step is to get the link of the youtube video which we need to scrape using python. Don't forget to place your 
# link between " " or ' ':

link = input("Enter Link of Youtube Video: ")
yt = YouTube(link)

# %%
# Now, as we have taken the link of a youtube video as an input, we will run the program while scraping 
# some information about the video. Now, I will write some necessary functions that we can use for scraping 
# youtube with python by using pytube 
# module:
# To print title
print("Title :", yt.title)
# To get number of views
print("Views :", yt.views)
# To get the length of video
print("Duration :", yt.length)
# To get description
print("Description :", yt.description)
# To get ratings
print("Ratings : ", yt.rating)

# %%
# The task of scraping youtube with python will be left incomplete if we do not know how to download the youtube video. 
# It's obvious that we are more considered about the data, but still, if you want to see how we can download the youtube 
# video using python then you can use the code below:

stream = yt.streams.get_highest_resolution()
stream.download()
print("Download completed!!")

# %% [markdown]
# # Stock Price Data Scrapping
# As machine learning practitioners, we need to collect stock price data for regression analysis and time series analysis. We can easily download it from Yahoo Finance. But imagine if we want to create an application where we can analyze the real-time stock prices, we need to collect the latest dataset instead of using the downloaded dataset. So this lesson will teach you how to get the stock price data between any time interval by using the Python programming language.
#
# Yahoo Finance is one of the most popular websites to collect stock price data. You need to visit the website, enter the company's name or stock symbol, and you can easily download the dataset. But if you want to get the latest dataset every time you are running your code, you need to use the yfinance API. yfinance is an API provided by Yahoo Finance to collect the latest stock price data.
#
# To use this API, you need to install it by using the pip command in your terminal or command prompt as mentioned below:
#
# pip install yfinance

# %%
# Now below is how you can get the latest stock price data using Python:

import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta

# %%
# Create a date object and create a date format to use as ending date
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
# We will create date interval to collect the stock price data from today to the last 360 days.
d2 = date.today() - timedelta(days=360)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

# %%
# Download stock price between the start and end date interval
data = yf.download('NEM', start=start_date, end=end_date, progress=False)

# %%
data.head()

# %%
# In this dataset, Date is not a column, it's the index of this dataset. To use this data for any data science
# task, we need to convert this index into a column. Below is how you can do that:

data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
data.head()

# %% [markdown]
# This brings us to the end of web scrapping class.
# Thanks for your time.
