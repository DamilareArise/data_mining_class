# %%
# Data Mining and extraction

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Web Scraping using Beautifulsoup
# Web Scraping means to collect data from the Internet. As a beginner in data science, you must have seen CSV files on the Internet distributed by some popular websites like Kaggle and other govt websites. The data is prepared by either collecting and writing using standard methods or by scraping it from the Internet.
# Web Scraping to Create a CSV File
# So we need two primary packages for this task, BeautifulSoup, urllib and Selenium. We can easily install both these packages using the pip command - pip install bs4, pip install urllib3, pip selenium.

# %%
# I will scrape data from Flipkart and create a CSV file from that data. It's not that difficult what it seems. Let's get
# our hands dirty with web scraping to create a CSV file using python. I will start by importing the necessary packages 
# that we need for this task. So let's get started.
from bs4 import BeautifulSoup as soup
# from urllib.request import urlopen as uReq
import requests

my_url="https://edu.sqi.ng/procert/"
# # uClient = uReq(my_url)
# # page_html = uClient.read()
# # uClient.close()
procert = requests.get(my_url)
page_html = procert.content

# %%
page_html
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<link rel="pingback" href="https://sqi.edu.ng/xmlrpc.php" />\n\n\t<script type="text/javascript">\n\t\tdocument.documentElement.className = \'js\';\n\t</script>\n\t\n\t<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin /><script id="diviarea-loader">window.DiviPopupData=window.DiviAreaConfig={"zIndex":1000000,"animateSpeed":400,"triggerClassPrefix":"show-popup-","idAttrib":"data-popup","modalIndicatorClass":"is-modal","blockingIndicatorClass":"is-blocking","defaultShowCloseButton":true,"withCloseClass":"with-close","noCloseClass":"no-close","triggerCloseClass":"close","singletonClass":"single","darkModeClass":"dark","noShadowClass":"no-shadow","altCloseClass":"close-alt","popupSelector":".et_pb_section.popup","initializeOnEvent":"et_pb_after_init_modules","popupWrapperClass":"area-outer-wrap","fullHeightClass":"full-height","openPopupCl
# ...

# %%
page_soup = soup(page_html, "html.parser")
page_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://sqi.edu.ng/xmlrpc.php" rel="pingback"/>
# <script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
# ...

# %%
# Now let's see how many HTML containers are present in this link:
list_of_section = page_soup.findAll("div", { "class": "et_pb_section"})
print(len(list_of_section))
# list_of_section
# print(soup.prettify(list_of_section[2]))
# Out:
# 12

# %%
container = list_of_section[7]
list_of_card = container.findAll("div", {"class": "et_pb_column"})
len(list_of_card)
# Out:
# 6

# %%
card = list_of_card[4]
print(card)
# Out:
# <div class="et_pb_column et_pb_column_1_3 et_pb_column_21 et_pb_css_mix_blend_mode_passthrough">
# <div class="et_pb_module et_pb_blurb et_pb_blurb_19 et_clickable et_pb_text_align_left et_pb_blurb_position_top et_pb_bg_layout_light">
# <div class="et_pb_blurb_content">
# ...

# %%
card_image_content = card.find('div', {'class': 'et_pb_main_blurb_image'})
card_image_content
card_link = card_image_content.find('a')['href']
card_link
# Out:
# 'https://edu.sqi.ng/procert-software-engineering'

# %%
card_image = card_image_content.find('img', {'class': 'et-waypoint'})['src']
card_image
# Out:
# 'https://edu.sqi.ng/wp-content/uploads/2023/01/software-engineering-630x330-1.webp'

# %%
title = card.find('h4', {'class': 'et_pb_module_header'}).find('a').text
title
# Out:
# 'SOFTWARE ENGINEERING'

# %%
description = card.find('div', {'class': 'et_pb_blurb_description'}).find('p').text
description
# Out:
# 'Software engineering is a discipline that combines engineering and computer science concepts in the development and maintenance of reliable, usable, and dependable software and at SQI…'

# %%
list(range(2, 8))
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
images = []
links = []
titles = []
descriptions = [] 

for x in range(2, 8):
    section = list_of_section[x]
    list_of_card = section.findAll("div", {"class": "et_pb_column"})
    for card in list_of_card:
    
        card_image_content = card.find('div', {'class': 'et_pb_main_blurb_image'})
        if card_image_content:
            card_link = card_image_content.find('a')['href']
            links.append(card_link)
            
            card_image = card_image_content.find('img', {'class': 'et-waypoint'})['src']
            images.append(card_image)
         
            title = card.find('h4', {'class': 'et_pb_module_header'}).find('a').text
            titles.append(title)
          
            description = card.find('div', {'class': 'et_pb_blurb_description'}).find('p').text
            descriptions.append(description)

print(len(images))
print(len(links))
print(len(titles))
print(len(descriptions))
# Out:
# 20
# 20
# 20
# 20

# %%
data = {
    "images": images,
    "links": links,
    "titles": titles,
    "descriptions": descriptions
}

procert = pd.DataFrame(data)
procert
# Out:
#                                                images  \
# 0   https://edu.sqi.ng/wp-content/uploads/2019/05/...
# 1   https://edu.sqi.ng/wp-content/uploads/2023/01/...
# 2   https://edu.sqi.ng/wp-content/uploads/2023/08/...
# 3   https://edu.sqi.ng/wp-content/uploads/2024/10/...
# 4   https://edu.sqi.ng/wp-content/uploads/2023/07/...
# 5   https://edu.sqi.ng/wp-content/uploads/2025/04/...
# 6   https://edu.sqi.ng/wp-content/uploads/2023/07/...
# 7   https://edu.sqi.ng/wp-content/uploads/2019/05/...
# 8   https://edu.sqi.ng/wp-content/uploads/2020/10/...
# 9   https://edu.sqi.ng/wp-content/uploads/2022/11/...
# 10  https://edu.sqi.ng/wp-content/uploads/2019/05/...
# 11  https://edu.sqi.ng/wp-content/uploads/2019/05/...
# 12  https://edu.sqi.ng/wp-content/uploads/2020/06/...
# 13  https://edu.sqi.ng/wp-content/uploads/2023/07/...
# 14  https://edu.sqi.ng/wp-content/uploads/2023/04/...
# 15  https://edu.sqi.ng/wp-content/uploads/2019/05/...
# ...

# %%
procert.to_csv("sqi_procert.csv", index=False)

# %% [markdown]
# ## Jumia Scraping

# %%
jumia = requests.get("https://www.jumia.com.ng/")
page_html = jumia.content

# %%
page_soup = soup(page_html, "html.parser")
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
containers = page_soup.find_all('div', {"class": "-phxs"})
len(containers)
# Out:
# 21

# %%
items = containers[0].findAll('div', {'class': 'itm col'})
len(items)
# Out:
# 15

# %%
card = items[0].find('a', {'class': 'core'})
product_link = card['href']
product_link
# Out:
# '/solar-compatible-rechargeable-standing-fan-c188-black-hc-mpg10224740.html'

# %%
image = card.find('img', {'class': 'img'})['data-src']
image
# Out:
# 'https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/45/3448404/1.jpg?0470'

# %%
title = card.find('div', {'class': 'name'}).text
title
# Out:
# 'Absolut Citron Vodka 1L'

# %%
actual_price = card.find('div', {'class': 'prc'})['data-oprc']
actual_price
# Out:
# '₦ 18,525'

# %%
selling_price = card.find('div', {'class': 'prc'}).text
float(selling_price.split()[1].replace(',', ''))
# Out:
# 6907.0

# %%
discount = card.find('div', {'class': '_dsct'}).text
discount
# Out:
# '9%'

# %%
links = []
images = []
titles = []
actual_prices = []
selling_prices = []
discounts = []

for container in containers:
    items = container.findAll('div', {'class': 'itm col'})
    for item in items:
        card = item.find('a', {'class': 'core'})
        if card:
            product_link = card.get('href')
            links.append(product_link)
            
            image = card.find('img', {'class': 'img'})
            if image:
                image = image.get('data-src')
                images.append(image)
            else:
                images.append(None)
            
            title = card.find('div', {'class': 'name'})
            if title:
                title = title.text
                titles.append(title)
            
            else:
                titles.append(None)
            
            actual_price = card.find('div', {'class': 'prc'})
            if actual_price:
                actual_price = actual_price.get('data-oprc')
                if actual_price:
                    actual_prices.append(float(actual_price.split()[1].replace(',', '')))
                else:
                    actual_prices.append(np.NaN)
            else:
                actual_prices.append(np.NaN)
            
            selling_price = card.find('div', {'class': 'prc'})
            if selling_price:
                selling_price = selling_price.text
                selling_prices.append(float(selling_price.split()[1].replace(',', '')))
            else:
                selling_prices.append(np.NaN)
            
            discount = card.find('div', {'class': '_dsct'})
            if discount:
                discount = discount.text
                discounts.append(discount)
            else:
                discounts.append(None)
        
print(len(links))           
print(len(images))        
print(len(titles))        
print(len(actual_prices))        
print(len(selling_prices)) 
print(len(discounts))
# Out:
# 276
# 276
# 276
# 276
# 276
# 276

# %%
data = {
    'link': links,
    'image': images,
    'title': titles,
    'actual price': actual_prices,
    'selling price': selling_prices,
    'discount': discounts
}

jumia = pd.DataFrame(data)
jumia
# Out:
#                                                   link  \
# 0    /solar-compatible-rechargeable-standing-fan-c1...
# 1    /easypie-easypie-20000mah-ultra-slim-power-ban...
# 2    /tropicwhirl-blender-2l-2-cups-model-1589-650w...
# 3    /natural-fairness-clarifiant-for-women-400ml-p...
# 4    /silver-crest-8l-extra-large-digital-airfryer-...
# ..                                                 ...
# 271  /glenmorangie-the-original-10-year-old-single-...
# 272  /beefeater-gin-england-london-dry-70cl-9680664...
# 273                /liquer-70cl-kahlua-mpg1657606.html
# 274         /hennessy-vsop-cognac-750ml-351570328.html
# 275             /absolut-citron-vodka-1l-96806563.html
#
#                                                  image  \
# 0    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 1    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 2    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 3    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# ...

# %% [markdown]
# ## JIJI Scraping

# %%
from bs4 import BeautifulSoup as soup
import requests

jiji = requests.get("https://jiji.ng/cars")
page_html = jiji.content

# %%
page_soup = soup(page_html, "html.parser")
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# Now let's see how many HTML containers are present in this link:
containers = page_soup.findAll("div", { "class": "masonry-column"})
len(containers)
# Out:
# 3

# %%
# print div for the first container
# print(soup.prettify(containers[0]))
containers[0]
# Out:
# <div class="masonry-column" style="width:33.333333333333336%;"><div data-column="0"><!--[--><div class="masonry-item" style=""><!--[--><!-- --><div class="b-list-advert__gallery__item js-advert-list-item"><a class="b-list-advert-base b-list-advert-base--gallery qa-advert-list-item" href="/amuwo-odofin/cars/mercedes-benz-c300-sport-sedan-rwd-2-0l-4cyl-7a-2016-black-9YnxQflkCyiYcgZiPWVwZw6P.html" style=""><div class="b-list-advert-base__img__wrapper b-list-advert-base__img__wrapper--one-image"><!--[--><!--[--><div class="b-list-advert-base__img js-list-advert-base-img" style="padding-bottom:75%;"><!-- --><picture class="h-flex-center h-width-100p h-height-100p h-overflow-hidden"><!--[--><source srcset="https://pictures-nigeria.jijistatic.net/171611727_MzAwLTIyNS1hYjIwY2ZiOTM2.webp 1x" type="image/webp"/><!--]--><img alt="Photo - Mercedes-Benz C300 Sport Sedan RWD (2.0L 4cyl 7A) 2016 Black" class="" data-nuxt-pic="" loading="eager" onerror="this.setAttribute('data-error', 1)" src="https
# ...

# %%
# Let us crap information for one product first
content = containers[0]
content = content.findAll("div", { "class": "masonry-item"})
len(content)
# Out:
# 7

# %%
# Let get the name of the product
card = content[0]
image = card.find('img')
image['src']
# Out:
# 'https://pictures-nigeria.jijistatic.net/180993903_MzAwLTIyNS0zYmQ0NGNmNjZm.webp'

# %%
label1 = card.find('div', {"class": "b-list-advert-base__pkg-label"})
label1

# %%
price = card.find('div', {'class': 'qa-advert-price'})
# labels[0].findAll('div', {'class': 'b-list-advert-base__label'})
price.text
# Out:
# '₦ 15,000,000'

# %%
title = card.find('div', {'class': 'b-advert-title-inner--div'})
title.text
# Out:
# 'Honda Accord 2009 Maroon'

# %%
description = card.find('div', {'class': 'b-list-advert-base__description-text'})
description.text
# Out:
# 'Foreign used Honda accord. Tin can cleared. July 2025 entry'

# %%
attr = card.findAll('div', {'class': 'b-list-advert-base__item-attr'})
attr1 = attr[0].text
attr2 = attr[1].text

print(attr1, attr2)
# Out:
# Foreign Used  Automatic

# %%
# 
location = card.findAll('div', {'class': 'b-list-advert-base__bottom-wrapper'})
location[0].findAll('div', {'class': 'b-list-advert-base__location'})
loc = location[0].text
loc
# loc.findAll('div', {'class': 'b-list-advert-base__location'})
# Out:
# ''

# %%
images = []
titles = []
descriptions = []
attrs1 = []
attrs2 = []
prices = []


for x in range(len(containers)):
    content = containers[x].findAll("div", { "class": "masonry-item"})
    for y in range(len(content)):
        card = content[y]
        image = card.find('img')
        if image:
            images.append(image['src'])
        
        price = card.find('div', {'class': 'qa-advert-price'})
        if price:
            prices.append(price.text.strip())
        
        description = card.find('div', {'class': 'b-list-advert-base__description-text'})
        if description:
            descriptions.append(description.text.strip())
            
        attr = card.findAll('div', {'class': 'b-list-advert-base__item-attr'})
        if len(attr) > 1:
            attr1 = attr[0].text
            attr2 = attr[1].text
            attrs1.append(attr1)
            attrs2.append(attr2)
        
        title = card.find('div', {'class': 'b-a    dvert-title-inner--div'})
        if title:
            titles.append(title.text.strip())     

print(len(images), len(titles), len(descriptions), len(attrs1), len(attrs2), len(prices))
# Out:
# 20 20 20 20 20 20

# %% [markdown]
# # Scrapping JavaScript Rendering page
# Many modern websites are dynamic, in which the content is loaded and populated using client JavaScript. Therefore, some extra setups are required in order to scrape data from JavaScript webpages.
# In this class, you’ll learn how to scrape contents from a JavaScript webpage using Selenium, BeautifulSoup, and Pandas.
# In order to run this example, you need to configure your system with the following steps.
# If you have pip on your system, you can simply install these libraries by
#
#
#     pip install selenium==3.8.0
#     pip install beautifulsoup4
#     pip install pandas
#
# # Download Selenium web driver
# Selenium requires a driver to interface with the chosen browser. For example, Chrome requires ChromeDriver, which needs to be installed before running the example.
# To install ChromeDriver, you should:
# download the same version ChromeDriver as the Chrome you are using.
# place the ChromeDriver executable in your PATH, for example, place it in /usr/bin or /usr/local/bin.
# You will get a WebDriverException error if you don’t have a proper Selenium web driver in your PATH.
#
# Note: Selenium also have suport for other browsers e.g Firefox etc. To use any of this drivers, you must download their web driver by following the same setup as chrome above.

# %%
# !pip install selenium
# Out:
# ...
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
# ...

# %%
from selenium import webdriver
import time
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup as soup

# driver = webdriver.Chrome()
# driver.get("https://www.flipkart.com/audio-video/pr?sid=0pm&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_efb87939-7c90-4539-9b7e-951ac70167d9_1_X1NCR146KC29_MC.10FP40LOO0ES&otracker=hp_rich_navigation_1_1.navigationCard.RICH_NAVIGATION_Electronics~Audio~All_10FP40LOO0ES&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_1_L2_view-all&cid=10FP40LOO0ES")
# # driver.get(url)
# time.sleep(10)
# html_source = driver.page_source
# driver.quit()


# Running selenium in headless mode i.e while executing it would'nt display the web browser
options = Options()
options.add_argument("headless")

driver = webdriver.Chrome(options=options)
driver.get("https://www.flipkart.com/audio-video/pr?sid=0pm&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_efb87939-7c90-4539-9b7e-951ac70167d9_1_X1NCR146KC29_MC.10FP40LOO0ES&otracker=hp_rich_navigation_1_1.navigationCard.RICH_NAVIGATION_Electronics~Audio~All_10FP40LOO0ES&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_1_L2_view-all&cid=10FP40LOO0ES")
time.sleep(3)
html_source = driver.page_source
driver.quit()

# %%
html_source
# Out:
# '<html lang="en"><head><script type="text/javascript" async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_mid=54483410890952808504260655912983739892&amp;d_cb=s_c_il%5B0%5D._setAudienceManagerFields"></script><script type="text/javascript" async="async" src="https://flipkart.d1.sc.omtrdc.net/id?d_visid_ver=1.5.4&amp;callback=s_c_il%5B0%5D._setAnalyticsFields&amp;mcorgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;mid=54483410890952808504260655912983739892"></script><script type="text/javascript" async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_cb=s_c_il%5B0%5D._setMarketingCloudFields"></script><link href="https://rukminim2.flixcart.com" rel="preconnect"><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css">
# ...

# %%
from selenium import webdriver
from selenium.webdriver.edge.options import Options


#Executing in head mode i.e while executing it would display the web browser
driver = webdriver.Edge()
driver.get('https://jiji.ng/cars')
html_source = driver.page_source 
driver.quit()


#Executing in headless mode i.e while executing it would'nt display the web browser
# options = Options()
# options.add_argument("headless")

# driver = webdriver.Edge(options = options)
# driver.get('https://jiji.ng/cars')
# html_source = driver.page_source 
# driver.quit()

# %%
page_soup = soup(html_source,'html.parser')
page_soup
# Out:
# <html lang="en"><head><script async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_mid=54483410890952808504260655912983739892&amp;d_cb=s_c_il%5B0%5D._setAudienceManagerFields" type="text/javascript"></script><script async="async" src="https://flipkart.d1.sc.omtrdc.net/id?d_visid_ver=1.5.4&amp;callback=s_c_il%5B0%5D._setAnalyticsFields&amp;mcorgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;mid=54483410890952808504260655912983739892" type="text/javascript"></script><script async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_cb=s_c_il%5B0%5D._setMarketingCloudFields" type="text/javascript"></script><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css" rel="stylesheet"/
# ...

# %%
container = page_soup.findAll('div', {'class': '_75nlfW'})
len(container)
# Out:
# 10

# %%
cards = container[0].findAll('div', {'class': 'slAVV4'})
len(cards)
card = cards[0]

# %%
image = card.find('img', {'class': 'DByuf4'})['src']
image
# Out:
# 'https://rukminim2.flixcart.com/image/612/612/xif0q/headphone/v/q/b/-original-imahff3mpemzuybg.jpeg?q=70'

# %%
title = card.find('a', {'class': 'wjcEIp'}).text
title
# Out:
# 'GOBOULT (previously Boult) Z40 with ENC Mic, 60H Batter...'

# %%
description = card.find('div', {'class': 'NqpwHC'}).text
description
# Out:
# 'White, Grey, In the Ear'

# %%
rating = card.find('div', {'class': 'XQDdHH'}).text
rating
# Out:
# '4.1'

# %%
review = card.find('span', {'class': 'Wphh3N'}).text.strip('()')
review
# Out:
# '4,16,615'

# %%
selling_price = card.find('div', {'class': 'Nx9bqj'}).text
selling_price
# Out:
# '₹799'

# %%
actual_price = card.find('div', {'class': 'yRaY8j'}).text
actual_price
# Out:
# '₹4,999'

# %%
discount = card.find('div', {'class': 'UkUFwK'}).find('span').text
discount
# Out:
# '84% off'

# %%
images = []
titles = []
descriptions = []
ratings = []
reviews = []
selling_prices = []
actual_prices = []
discounts = []

for x in range(len(container)):
    cards = container[x].findAll('div', {'class': 'slAVV4'})
    for y in range(len(cards)):
        image = cards[y].find('img', {'class': 'DByuf4'})['src']
        images.append(image) if image else images.append(np.nan)
        
        title = cards[0].find('a', {'class': 'wjcEIp'}).text
        titles.append(title) if title else titles.append(np.nan)
        
        description = card.find('div', {'class': 'NqpwHC'}).text
        descriptions.append(description) if description else descriptions.append(np.nan)
        
        rating = card.find('div', {'class': 'XQDdHH'}).text
        ratings.append(rating) if rating else ratings.append(np.nan)
        
        review = card.find('span', {'class': 'Wphh3N'}).text.strip('()')
        reviews.append(review) if review else reviews.append(np.nan)
        
        selling_price = card.find('div', {'class': 'Nx9bqj'}).text
        selling_prices.append(selling_price) if selling_price else selling_prices.append(np.nan)
        
        actual_price = card.find('div', {'class': 'yRaY8j'}).text
        actual_prices.append(actual_price) if actual_price else actual_prices.append(np.nan)
        
        discount = card.find('div', {'class': 'UkUFwK'}).find('span').text
        discounts.append(discount) if discount else discounts.append(np.nan)
        
print(len(titles))
print(len(images))
print(len(descriptions))
print(len(ratings))
print(len(reviews))
print(len(selling_prices))
print(len(actual_prices))
print(len(discounts))
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40

# %%
driver = webdriver.Chrome(options=options)
    
images = []
titles = []
descriptions = []
ratings = []
reviews = []
selling_prices = []
actual_prices = []
discounts = []
for i in range(1, 3):
    driver.get(f"https://www.flipkart.com/audio-video/pr?sid=0pm&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_efb87939-7c90-4539-9b7e-951ac70167d9_1_X1NCR146KC29_MC.10FP40LOO0ES&otracker=hp_rich_navigation_1_1.navigationCard.RICH_NAVIGATION_Electronics%7EAudio%7EAll_10FP40LOO0ES&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_1_L2_view-all&cid=10FP40LOO0ES&page={i}")
    time.sleep(6)
    html_source = driver.page_source
    driver.quit()
    
    page_soup = soup(html_source,'html.parser')
    container = page_soup.findAll('div', {'class': '_75nlfW'})

    for x in range(len(container)):
        cards = container[x].findAll('div', {'class': 'slAVV4'})
        for y in range(len(cards)):
            image = cards[y].find('img', {'class': 'DByuf4'})['src']
            images.append(image) if image else images.append(np.nan)
            
            title = cards[0].find('a', {'class': 'wjcEIp'}).text
            titles.append(title) if title else titles.append(np.nan)
            
            description = card.find('div', {'class': 'NqpwHC'}).text
            descriptions.append(description) if description else descriptions.append(np.nan)
            
            rating = card.find('div', {'class': 'XQDdHH'}).text
            ratings.append(rating) if rating else ratings.append(np.nan)
            
            review = card.find('span', {'class': 'Wphh3N'}).text.strip('()')
            reviews.append(review) if review else reviews.append(np.nan)
            
            selling_price = card.find('div', {'class': 'Nx9bqj'}).text
            selling_prices.append(selling_price) if selling_price else selling_prices.append(np.nan)
            
            actual_price = card.find('div', {'class': 'yRaY8j'}).text
            actual_prices.append(actual_price) if actual_price else actual_prices.append(np.nan)
            
            discount = card.find('div', {'class': 'UkUFwK'}).find('span').text
            discounts.append(discount) if discount else discounts.append(np.nan)
            
print(len(titles))
print(len(images))
print(len(descriptions))
print(len(ratings))
print(len(reviews))
print(len(selling_prices))
print(len(actual_prices))
print(len(discounts))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Welcome\anaconda3\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File c:\Users\Welcome\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\Welcome\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
# ...

# %% [markdown]
# # WEBSCRAPPING USING APIs

# %% [markdown]
# # Wikipedia Scraping
# Wikipedia is one of those largest platforms which provides almost every information for free. From your kindergarten till today, you must have visited this platform atleast once to get any information from school presentations to professional research, Wikipedia helps everybody.
# Unlike other sources of information websites, Wikipedia has its API to scrape data from its articles. Python being a general-purpose programming language provides packages for almost every task. So we have a package named as wikipedia for Python which we can use to scrape Wikipedia articles using Python. To scrape useful information from Wikipedia, you need to install a package named as wikipedia, which can be easily
# installed using the pip command- pip install wikipedia.

# %%
# Using requests module

import requests

def get_wiki_summary(title):
    url = f"https://en.wikipedia.org/api/rest_v1/page/summary/{title}"
    headers = {
        "User-Agent": "MyApp/1.0 (arisedamilare5@gmail.com)"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# %%
data = get_wiki_summary("Python_(programming_language)")
data.get('extract')
# Out:
# 'Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.'

# %%
# using wikipedia module
# !pip install wikipedia

# %%
# import wilipedia as wiki
import wikipedia as wiki
wiki.__version__
# Out:
# (1, 4, 0)

# %%
# To explain the use of this package, I will scrape information based on Python. So let's start with the task to scrape
# Wikipedia articles. The code below will get all the search suggestions of our input. In our case, it will return the 
# search suggestions of Python:
print(wiki.search("python"))
# Out:
# ['Python (programming language)', 'Python', 'Monty Python', 'Python (codename)', 'Ball python', 'Burmese python', 'Reticulated python', 'Python (missile)', 'Burmese pythons in Florida', 'Monty Python and the Holy Grail']

# %%
# Now let's see will the search engine on Wikipedia suggest us python if we will type only some alphabets of its spelling:
print(wiki.suggest("Pyth"))
# Out:
# pith

# %%
# Yes, it works, now let's have a look how we can get the summary of an article on Wikipedia:
print(wiki.summary("Python (programming language)"))
# Out:
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.
# Python is dynamically type-checked and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming.
# Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision not completely backward-compatible with earlier versions. Recent versions, such as Python 3.12, have added capabilites and keywords for typing (and more; e.g. increasing speed); helping with (optional) static typing. Currently only versions in the 3.x series are supported.
# Python consistently ranks as one of the most popular programming languages, and it has gained widespread use in the machine learning community. It is widely taught as an introductory programming language.

# %%
# If you want to read the summary in another language other than English, we can also do that. I will get the same summary
# above in the French language:
wiki.set_lang("fr")
print(wiki.summary("Python (programming language)"))
# Out:
# Python (prononcé /pi.tɔ̃/) est un langage de programmation interprété, multiparadigme et multiplateformes. Il favorise la programmation impérative structurée, fonctionnelle et orientée objet. Il est doté d'un typage dynamique fort, d'une gestion automatique de la mémoire par ramasse-miettes et d'un système de gestion d'exceptions ; il est ainsi similaire à Perl, Ruby, Scheme, Smalltalk et Tcl.
# Le langage Python est placé sous une licence libre proche de la licence BSD et fonctionne sur la plupart des plateformes informatiques, des smartphones aux ordinateurs centraux, de Windows à Unix avec notamment GNU/Linux en passant par macOS, ou encore Android, iOS, et peut aussi être traduit en Java ou .NET. Il est conçu pour optimiser la productivité des programmeurs en offrant des outils de haut niveau et une syntaxe simple à utiliser.
# ...

# %%
# Now let's change the language back to English and have a look at some more insights from the article. Here I will 
# scrape all the information we will get if we will read about python on Wikipedia:
wiki.set_lang("en")
p = wiki.page("Python (programming language)")
p
# Out:
# <WikipediaPage 'Python (programming language)'>

# %%
# To get the Title:
print(p.title)
# Out:
# Python (programming language)

# %%
# To get the url of the article:
print(p.url)
# Out:
# https://en.wikipedia.org/wiki/Python_(programming_language)

# %%
# To scrape the full article:
print(p.content)
# Out:
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.
# Python is dynamically type-checked and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming.
# Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision not completely backward-compatible with earlier versions. Recent versions, such as Python 3.12, have added capabilites and keywords for typing (and more; e.g. increasing speed); helping with (optional) static typing. Currently only versions in the 3.x series are supported.
# Python consistently ranks as one of the most popular programming languages, and it has gained widespread use in the machine learning community. It is widely taught as an introductory programming language.
#
#
# ...

# %%
# To get all the images in the article:
print(p.images)
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/a/a9/Af-Helloworld_%28C_Sharp%29.svg', 'https://upload.wikimedia.org/wikipedia/commons/3/31/Free_and_open-source_software_logo_%282009%29.svg', 'https://upload.wikimedia.org/wikipedia/commons/2/21/Guido_van_Rossum_in_PyConUS24.jpg', 'https://upload.wikimedia.org/wikipedia/commons/2/20/Hello_World_in_Python.png', 'https://upload.wikimedia.org/wikipedia/commons/6/6f/Octicons-terminal.svg', 'https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg', 'https://upload.wikimedia.org/wikipedia/commons/e/e0/Python_3.13_Standrd_Type_Hierarchy-en.svg', 'https://upload.wikimedia.org/wikipedia/commons/b/bd/Python_Powered.png', 'https://upload.wikimedia.org/wikipedia/commons/f/f8/Tiobeindex.png', 'https://upload.wikimedia.org/wikipedia/commons/d/df/Wikibooks-logo-en-noslogan.svg', 'https://upload.wikimedia.org/wikipedia/commons/f/fa/Wikibooks-logo.svg', 'https://upload.wikimedia.org/wikipedia/commons/f/ff/Wikidata-logo.svg', 'https
# ...

# %%
# And to get all the referals used by Wikipedia in the article:
p.links
# Out:
# ['"Hello, World!" program',
#  '3ds Max',
#  '?:',
#  'ABC (programming language)',
#  'ADMB',
#  'ALGOL',
#  'ALGOL 68',
#  'API',
#  'APL (programming language)',
#  'ATmega',
#  'AVR microcontrollers',
#  'Abaqus',
#  'Academic Free License',
#  'Academic conference',
#  'Ada (programming language)',
#  'Advanced Simulation Library',
#  'Affix',
#  'Ahead-of-time compilation',
#  'Alex Martelli',
#  'Algebra',
#  'Alternative terms for free software',
#  'Amazon (company)',
#  'AmigaOS 4',
#  'Amoeba (operating system)',
#  'Anaconda (installer)',
#  'Analyse-it',
#  'Android (operating system)',
#  'Anonymous function',
#  'Apache Groovy',
#  'Apache License',
#  'Apache webserver',
#  'Apple M1',
#  'Apple Public Source License',
#  'ArXiv (identifier)',
#  'Arbitrary-precision arithmetic',
#  'ArcGIS',
#  'Arithmetic operations',
#  'Array index',
#  'Array slicing',
#  'Artificial intelligence',
#  'Artistic License',
#  'Aspect-oriented programming',
#  'Assembly language',
# ...

# %% [markdown]
# # Twitter Scraping
# One of the hot topics in data science is social media analytics. People love these analyzes and interest them because everyone knows this world. Most of our time is spent on Twitter, Instagram, Facebook, and some other social media apps. The use of social media analysis is mostly used in the tasks of relationship analysis. With not only scraping twitter with python, but I will also do some relationship analysis based on our scrapped data.
#
# Scraping Twitter with Python
# Now, let's start with our task. In this task of scraping twitter with python, we need to install a package known as twint, which can be easily installed by using the pip command in your terminal - pip install twint.

# %%
import twint
import pandas as pd
from collections import Counter
import nest_asyncio

nest_asyncio.apply()

# %%
c = twint.Config()
c.Search = "lockdown"
c.Limit = 5000
c.Store_csv = True
c.Output = 'lockdown_tweet_data.csv'
twint.run.Search(c)

# %%
# c = twint.Config()
# c.Username = 'segalink'
# twint.run.Followers(c)

c = twint.Config()
c.Username = "segalink"
c.Limit = 500
c.Store_csv = True
c.User_full = True
c.Output = "users.csv"
twint.run.Followers(c)

# %%
# After importing the necessary libraries, now we need to start by creating a user list consisting of Twitter accounts. 
# We will analyze the relationships between the Twitter accounts of these people that I will add in the list below:

users = [
    'Elonmusk',
    'Arsenal',
    'Leereports',
    'segalink',
]

# %%
# Scraping Twitter with Python and Analyzing Relationships
# Now let's start by scraping Twitter with python and to analyze the relationships between all the Twitter accounts in our
# list above, I'll write a function named get_followings which will send a request to the twint library with a username. 
# This function will return a list of users that our input user follows:

def get_followings(username):

    c = twint.Config()
    c.Username = username
    c.Pandas = True

    twint.run.Following(c)
    list_of_followings = twint.storage.panda.Follow_df

    return list_of_followings['following'][username]

# %%
# The for loop below will create two variables, as sometimes we get index error when Twitter does not respond to our 
# request. For such cases, I added an exception to the code to ignore these users:

followings = {}
following_list = []
for person in users:
    print('#####\nStarting: ' + person + '\n#####')
    try:
        followings[person] = get_followings(person)
        following_list = following_list + followings[person]
    except KeyError:
        print('IndexError')

# %%
# After getting all of the following lists, we can just calculate the most common values in the following_list variable 
# to get the most popular accounts among our users. To get the 10 most followed accounts, we will use the Counter function
# of the collection library:

Counter(following_list).most_common(10)

# %%
# What if we want to see who's following who in our user group? To study it, I wrote a for loop that checks if anyone among 
# the users is in the following list of another person. As a result, it creates a list dictionary displaying the following
# states represented by True and False:

follow_relations ={}
for following_user in followings.keys():
    follow_relation_list = []
    for followed_user in followings.keys():
        if followed_user in followings[following_user]:
            follow_relation_list.append(True)
        else:
            follow_relation_list.append(False)
    follow_relations[following_user] = follow_relation_list

# %%
# In the code below, the resulting dictionary is transformed into a pandas dataframe for a more user-friendly 
# visualization. The rows of the dataframe show the users who follow, while the columns show the users who are followed:

following_df = pd.DataFrame.from_dict(follow_relations, 
                                      orient='index', columns=followings.keys())
following_df

# %% [markdown]
# # Instagram Scraping
# First of all, if you are learning Data Science then scraping Instagram will help you in getting the new trends of businesses, so that you can generate more leads and can reach out for your new potential customers.
# To scrap Instagram, we will use a library know as instaloader which provides us with an API for scraping Instagram. You can install this library by using the pip method in your terminal - pip install instaloader. Now If you have installed this package then let's get started with the task.

# %%
# Import the module
import instaloader

# %%
# Create an instance of Instaloader class
bot = instaloader.Instaloader()

# Load a profile from an Instagram handle
profile = instaloader.Profile.from_username(bot.context, 'nigerianbulletin')
print(type(profile))
print(profile)

# %%
# Now let's see how we can extract some valuable information from an Instagram profile:

print("Username: ", profile.username)
print("User ID: ", profile.userid)
print("Number of Posts: ", profile.mediacount)
print("Followers: ", profile.followers)
print("Followees: ", profile.followees)
print("Bio: ", profile.biography,profile.external_url)

# %%
# Login with username and password in the script
profile=bot.login(user="arisedamilare",passwd="")
print(profile)

# %%
# Interactive login on terminal
profile = bot.interactive_login("arisedamilare") # Asks for password in the terminal
print(profile)

# %%
# Scraping your followers and followees will help you in getting a list of their usernames, which you will require to do 
# when you will work in a professional environment in the data science field:

# Retrieve the usernames of all followers
followers = [follower.username for follower in profile.get_followers()]
print(followers)
print(len(followers))

# %%
# Retrieve the usernames of all followees
followees = [followee.username for followee in profile.get_followees()]
print(followees)

# %%
# Getting posts from any profile is easy in python. We just need to use get_posts(). I will use this method on the
# profile of someone else. To download each post, we need to loop over the generator object using .download_post() method.
# Now let's  go through this:

# Load a new profile
profile = instaloader.Profile.from_username(bot.context, 'nigerianbulletin')

# Get all posts in a generator object
posts = profile.get_posts()
posts

# %%
# Iterate and download
# It will save the post folder by creating its directory. In each folder, you will see the actual content of the posts of
# the profile like a video or images.

for index, post in enumerate(posts, 1):
    bot.download_post(post, target=f"{profile.username}_{index}")

# %% [markdown]
# # Youtube Scraping
# For the task of scraping youtube with python, we have a package known as pytube3, which can be easily installed by using the pip command - pip install pytube3. Now let's get started with the task of scraping youtube by importing this package:

# %%
# using youtube API. for python
# AIzaSyCDC8sVnYXBjmlzlqbRP1zq5vRvbAIG8Lg
# !pip install google-api-python-client
# Out:
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
# ...

# %%
from googleapiclient.discovery import build

youtube = build('youtube', 'v3', developerKey='AIzaSyCDC8sVnYXBjmlzlqbRP1zq5vRvbAIG8Lg')

request = youtube.search().list(
    q='sqi',
    part = 'snippet',
    type = 'video',
    maxResults = 10
)

res = request.execute()
res
# res.get('items')
for i in res['items']:
    print(i['snippet']['title'])
# Out:
# Tips and sample questions for the scholarship test
# sqi   Shoppers&#39; Discounting Partner
# Day 1 of SQI Data Science Week - Osogbo Campus🤗
# My SQI Story | Oluwatomigba Taiwo
# NIU SQi is an electric bike disguised as a motorcycle with 25 kph top speed
# SQI ANTHEM FULL LYRICS VIDEO
# SQI College of ICT launches new AI &amp; ROBOTICS RESEARCH and TRAINING Campus
# Learning at SQI College of ICT is an exciting journey!
# #Shorts #Headshot #OneTap #ProPlayer #UnderratedGamer #ClutchMoment #InsaneHeadshot #NextLevel
# SQI Jacket Preview Winter 22/23

# %%
# !pip install pytube3

# %%
# You will notice that we have and installed pytube3 by using the pip command, but we are importing pytube and not pytube3.
# To eliminate confusion, pytube3 is also imported by writing only pytube. We don't import it by writing as pytube3.
from pytube import YouTube

# %%
# Our next step is to get the link of the youtube video which we need to scrape using python. Don't forget to place your 
# link between " " or ' ':

link = input("Enter Link of Youtube Video: ")
yt = YouTube(link)

# %%
yt.title
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 yt.title
#
# File c:\Users\Welcome\anaconda3\Lib\site-packages\pytube\__main__.py:341, in YouTube.title(self)
#     338     return self._title
#     340 try:
# --> 341     self._title = self.vid_info['videoDetails']['title']
#     342 except KeyError:
#     343     # Check_availability will raise the correct exception in most cases
#     344     #  if it doesn't, ask for a report.
#     345     self.check_availability()
#
# File c:\Users\Welcome\anaconda3\Lib\site-packages\pytube\__main__.py:246, in YouTube.vid_info(self)
#     242     return self._vid_info
#     244 innertube = InnerTube(use_oauth=self.use_oauth, allow_cache=self.allow_oauth_cache)
# --> 246 innertube_response = innertube.player(self.video_id)
#     247 self._vid_info = innertube_response
#     248 return self._vid_info
#
# ...

# %%
# Now, as we have taken the link of a youtube video as an input, we will run the program while scraping 
# some information about the video. Now, I will write some necessary functions that we can use for scraping 
# youtube with python by using pytube 
# module:
# To print title
print("Title :", yt.title)
# To get number of views
print("Views :", yt.views)
# To get the length of video
print("Duration :", yt.length)
# To get description
print("Description :", yt.description)
# To get ratings
print("Ratings : ", yt.rating)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       1 # Now, as we have taken the link of a youtube video as an input, we will run the program while scraping
#       2 # some information about the video. Now, I will write some necessary functions that we can use for scraping
#       3 # youtube with python by using pytube
#       4 # module:
#       5 # To print title
# ----> 6 print("Title :", yt.title)
#       7 # To get number of views
#       8 print("Views :", yt.views)
#
# File c:\Users\Welcome\anaconda3\Lib\site-packages\pytube\__main__.py:341, in YouTube.title(self)
#     338     return self._title
#     340 try:
# --> 341     self._title = self.vid_info['videoDetails']['title']
#     342 except KeyError:
#     343     # Check_availability will raise the correct exception in most cases
#     344     #  if it doesn't, ask for a report.
# ...

# %%
# The task of scraping youtube with python will be left incomplete if we do not know how to download the youtube video. 
# It's obvious that we are more considered about the data, but still, if you want to see how we can download the youtube 
# video using python then you can use the code below:

stream = yt.streams.get_highest_resolution()
stream.download()
print("Download completed!!")

# %% [markdown]
# # Stock Price Data Scrapping
# As machine learning practitioners, we need to collect stock price data for regression analysis and time series analysis. We can easily download it from Yahoo Finance. But imagine if we want to create an application where we can analyze the real-time stock prices, we need to collect the latest dataset instead of using the downloaded dataset. So this lesson will teach you how to get the stock price data between any time interval by using the Python programming language.
#
# Yahoo Finance is one of the most popular websites to collect stock price data. You need to visit the website, enter the company's name or stock symbol, and you can easily download the dataset. But if you want to get the latest dataset every time you are running your code, you need to use the yfinance API. yfinance is an API provided by Yahoo Finance to collect the latest stock price data.
#
# To use this API, you need to install it by using the pip command in your terminal or command prompt as mentioned below:
#
# pip install yfinance

# %%
# Now below is how you can get the latest stock price data using Python:

import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta

# %%
# Create a date object and create a date format to use as ending date
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
# We will create date interval to collect the stock price data from today to the last 360 days.
d2 = date.today() - timedelta(days=360)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

# %%
# Download stock price between the start and end date interval
data = yf.download('AAPL', start=start_date, end=end_date, progress=False)
# Out:
# YF.download() has changed argument auto_adjust default to True

# %%
data.tail()
# Out:
# Price        Date        Open        High         Low       Close    Volume
# Ticker                   AAPL        AAPL        AAPL        AAPL      AAPL
# 241    2025-08-26  226.869995  229.490005  224.690002  229.309998  54575100
# 242    2025-08-27  228.610001  230.899994  228.259995  230.490005  31259500
# 243    2025-08-28  230.820007  233.410004  229.339996  232.559998  38074700
# 244    2025-08-29  232.509995  233.380005  231.369995  232.139999  39418400
# 245    2025-09-02  229.250000  230.850006  226.970001  229.720001  43804400

# %%
# In this dataset, Date is not a column, it's the index of this dataset. To use this data for any data science
# task, we need to convert this index into a column. Below is how you can do that:

data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
# Price        Date        Open        High         Low       Close    Volume
# Ticker                   AAPL        AAPL        AAPL        AAPL      AAPL
# 0      2024-09-09  219.797063  220.244975  215.706102  219.886642  67180000
# 1      2024-09-10  217.905858  220.453996  215.726000  219.090347  51591000
# 2      2024-09-11  220.434102  222.056541  216.880633  221.628540  44587100
# 3      2024-09-12  221.469284  222.514423  218.801706  221.738037  37455600
# 4      2024-09-13  222.544283  223.002143  220.882021  221.469284  36766600

# %% [markdown]
# This brings us to the end of web scrapping class.
# Thanks for your time.
